# %% [markdown]
# # Junior Job Data Cleaning
#
# This notebook is just to clean data that will go into Tableau. We have text data so we need something like Python to do this. The end goal is to look at different types of jobs and filter by them to see what trends occur in junior level positions.

# %%
import numpy as np
import pandas as pd
import string
import re
import ast
import nltk
from nltk.corpus import stopwords
from collections import Counter

# %%
orig_df = pd.read_csv('Jobs_Data.csv')

#want to keep original just in case, since a lot of changes will occur
df = orig_df.copy()

df.head()
# Out:
#                                    company  \
# 0                                   Novovu
# 1                   Coalition Technologies
# 2  Get It Recruit - Information Technology
# 3                                     SiLo
# 4                               eDiligence
#
#                                          description                focus  \
# 0  [b]We are looking for a talented frontend web ...   Frontend Developer
# 1  [heading2]WHY YOU SHOULD APPLY:[/heading2]\r\n...   Frontend Developer
# 2  [heading2]Job Description[/heading2]\r\n\r\nAs...    Backend Developer
# 3  [b]Based in Downtown Nashville, Simple Logisti...  Fullstack Developer
# 4  [center][size=4][b]Entry Level Full Stack Deve...  Fullstack Developer
#
#                                           jobTitle  \
# 0  Frontend Developer (HTML, CSS, and JS) - Remote
# 1                              Front End Developer
# 2                Software Developer - Remote | WFH
# 3                 Junior .NET Full Stack Developer
# 4                   Entry Level Software Developer
#
#                                                 link  \
# 0  https://lensa.com/frontend-developer-html-css-...
# 1  https://www.virtualvocations.com/job/remote-fr...
# 2  https://www.linkedin.com/jobs/view/software-de...
# 3  https://jobs.wjhl.com/jobs/junior-.net-full-st...
# 4  https://jooble.org/jdp/-2571818786162603564/En...
#
#                      location            postedDate          remote  \
# 0    Fort Washington, PA, USA  Jul 14, 2023 8:00 am     100% Remote
# 1                         NaN  Jul 14, 2023 8:01 am     100% Remote
# 2  King George, VA 22485, USA  Jul 14, 2023 8:03 am  100% In-Office
# 3          Nashville, TN, USA  Jul 14, 2023 8:04 am  100% In-Office
# 4        Los Angeles, CA, USA  Jul 14, 2023 8:05 am     Hybrid Work
#
#   salaryCurrency     salaryRange       type yearsOfExperience
# 0              $              []  Full-time          0-1 year
# 1              $         [15,35]  Full-time          0-1 year
# 2              $  [72000,182000]  Full-time          0-1 year
# 3              $              []  Full-time          0-1 year
# 4              $              []  Full-time          0-1 year

# %%
df.describe()
# Out:
#            company                                        description  \
# count         1426                                               1422
# unique         943                                               1202
# top     Guidehouse  [b]Position Summary...[/b]\r\n\r\nWhat you'll ...
# freq            27                                                 15
#
#                focus      jobTitle  \
# count           1426          1426
# unique            85           845
# top     Data Analyst  Data Analyst
# freq             210            48
#
#                                                      link       location  \
# count                                                1426           1057
# unique                                               1244            367
# top     https://www.ziprecruiter.com/c/Reesby/Job/UI-U...  United States
# freq                                                   10             54
#
#                  postedDate       remote salaryCurrency salaryRange  \
# count                  1426         1426           1424        1426
# unique                  895            3              1         261
# top     Aug 1, 2023 8:00 pm  Hybrid Work              $          []
# freq                     17          595           1424        1032
#
#              type yearsOfExperience
# count        1426              1426
# unique          3                 4
# top     Full-time          0-1 year
# freq         1353               879

# %%
countCompany = Counter(df['company'])

max(countCompany.values())
# Out:
# 27

# %%
def get_key_by_value(dictionary, target_value):
    for key, value in dictionary.items():
        if value == target_value:
            return key
    return None

# %%
get_key_by_value(countCompany, 27)
# Out:
# 'Guidehouse'

# %% [markdown]
# Most common company is Guidehouse with only 27 occurences, so this is not a significant feature to look at, especially if broken down by job title.

# %% [markdown]
# Get the hour of the job posting.

# %%
df['postingHour'] = df['postedDate'].apply(lambda x: x[-7] + ' ' + x[-2:])

# %%
Counter(df['postingHour'])
# Out:
# Counter({'8 am': 1094,
#          '9 am': 149,
#          '0 am': 66,
#          '5 pm': 10,
#          '4 am': 4,
#          '1 pm': 17,
#          '6 am': 7,
#          '2 am': 3,
#          '3 pm': 6,
#          '1 am': 5,
#          '7 pm': 6,
#          '8 pm': 33,
#          '0 pm': 3,
#          '7 am': 3,
#          '6 pm': 3,
#          '5 am': 2,
#          '2 pm': 6,
#          '3 am': 3,
#          '9 pm': 2,
#          '4 pm': 4})

# %%
df.head()
# Out:
#                                    company  \
# 0                                   Novovu
# 1                   Coalition Technologies
# 2  Get It Recruit - Information Technology
# 3                                     SiLo
# 4                               eDiligence
#
#                                          description                focus  \
# 0  [b]We are looking for a talented frontend web ...   Frontend Developer
# 1  [heading2]WHY YOU SHOULD APPLY:[/heading2]\r\n...   Frontend Developer
# 2  [heading2]Job Description[/heading2]\r\n\r\nAs...    Backend Developer
# 3  [b]Based in Downtown Nashville, Simple Logisti...  Fullstack Developer
# 4  [center][size=4][b]Entry Level Full Stack Deve...  Fullstack Developer
#
#                                           jobTitle  \
# 0  Frontend Developer (HTML, CSS, and JS) - Remote
# 1                              Front End Developer
# 2                Software Developer - Remote | WFH
# 3                 Junior .NET Full Stack Developer
# 4                   Entry Level Software Developer
#
#                                                 link  \
# 0  https://lensa.com/frontend-developer-html-css-...
# 1  https://www.virtualvocations.com/job/remote-fr...
# 2  https://www.linkedin.com/jobs/view/software-de...
# 3  https://jobs.wjhl.com/jobs/junior-.net-full-st...
# 4  https://jooble.org/jdp/-2571818786162603564/En...
#
#                      location            postedDate          remote  \
# 0    Fort Washington, PA, USA  Jul 14, 2023 8:00 am     100% Remote
# 1                         NaN  Jul 14, 2023 8:01 am     100% Remote
# 2  King George, VA 22485, USA  Jul 14, 2023 8:03 am  100% In-Office
# 3          Nashville, TN, USA  Jul 14, 2023 8:04 am  100% In-Office
# 4        Los Angeles, CA, USA  Jul 14, 2023 8:05 am     Hybrid Work
#
#   salaryCurrency     salaryRange       type yearsOfExperience postingHour
# 0              $              []  Full-time          0-1 year        8 am
# 1              $         [15,35]  Full-time          0-1 year        8 am
# 2              $  [72000,182000]  Full-time          0-1 year        8 am
# 3              $              []  Full-time          0-1 year        8 am
# 4              $              []  Full-time          0-1 year        8 am

# %% [markdown]
# Office location, years of experience, and type features need no cleaning:

# %%
Counter(df['remote'])
# Out:
# Counter({'100% Remote': 333, '100% In-Office': 498, 'Hybrid Work': 595})

# %%
Counter(df['type'])
# Out:
# Counter({'Full-time': 1353, 'Part-time': 38, 'Internship': 35})

# %%
Counter(df['yearsOfExperience'])
# Out:
# Counter({'0-1 year': 879, '1-3 years': 545, '5+ years': 1, '3-5 years': 1})

# %% [markdown]
# Almost all salaries are in $, and two are nan, so we can ignore this feature.

# %%
Counter(df['salaryCurrency'])
# Out:
# Counter({'$': 1424, nan: 2})

# %% [markdown]
# Want to split the salary range into two features.

# %%
#since the original feature is a string
df['salaryRange'] = df['salaryRange'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) and x != '[]' else np.nan)

# %%
df['minSalary'] = df['salaryRange'].apply(lambda x: x[0] if x is not np.nan else np.nan)
df['maxSalary'] = df['salaryRange'].apply(lambda x: x[1] if x is not np.nan else np.nan)

# %%
df.head(7)
# Out:
#                                    company  \
# 0                                   Novovu
# 1                   Coalition Technologies
# 2  Get It Recruit - Information Technology
# 3                                     SiLo
# 4                               eDiligence
# 5                           Leidos Holding
# 6                               BigBear.ai
#
#                                          description                focus  \
# 0  [b]We are looking for a talented frontend web ...   Frontend Developer
# 1  [heading2]WHY YOU SHOULD APPLY:[/heading2]\r\n...   Frontend Developer
# 2  [heading2]Job Description[/heading2]\r\n\r\nAs...    Backend Developer
# 3  [b]Based in Downtown Nashville, Simple Logisti...  Fullstack Developer
# 4  [center][size=4][b]Entry Level Full Stack Deve...  Fullstack Developer
# 5  [center][size=5]Description[/size][/center]\r\...  Fullstack Developer
# 6  [heading2]Overview[/heading2]\r\n\r\nBigBear.a...  Fullstack Developer
#
#                                           jobTitle  \
# 0  Frontend Developer (HTML, CSS, and JS) - Remote
# 1                              Front End Developer
# 2                Software Developer - Remote | WFH
# 3                 Junior .NET Full Stack Developer
# 4                   Entry Level Software Developer
# 5                      Junior Full Stack Developer
# 6                         Jr. Full Stack Developer
#
#                                                 link  \
# 0  https://lensa.com/frontend-developer-html-css-...
# 1  https://www.virtualvocations.com/job/remote-fr...
# 2  https://www.linkedin.com/jobs/view/software-de...
# 3  https://jobs.wjhl.com/jobs/junior-.net-full-st...
# 4  https://jooble.org/jdp/-2571818786162603564/En...
# 5  https://clearedcareers.com/job/319461/junior-f...
# 6  https://getwork.com/details/bcdec3380ac6383c52...
#
#                      location            postedDate          remote  \
# 0    Fort Washington, PA, USA  Jul 14, 2023 8:00 am     100% Remote
# 1                         NaN  Jul 14, 2023 8:01 am     100% Remote
# 2  King George, VA 22485, USA  Jul 14, 2023 8:03 am  100% In-Office
# 3          Nashville, TN, USA  Jul 14, 2023 8:04 am  100% In-Office
# 4        Los Angeles, CA, USA  Jul 14, 2023 8:05 am     Hybrid Work
# 5   Colorado Springs, CO, USA  Jul 14, 2023 8:06 am     Hybrid Work
# 6         Washington, MA, USA  Jul 14, 2023 8:07 am     100% Remote
#
#   salaryCurrency      salaryRange       type yearsOfExperience postingHour  \
# 0              $              NaN  Full-time          0-1 year        8 am
# 1              $         [15, 35]  Full-time          0-1 year        8 am
# 2              $  [72000, 182000]  Full-time          0-1 year        8 am
# 3              $              NaN  Full-time          0-1 year        8 am
# 4              $              NaN  Full-time          0-1 year        8 am
# 5              $  [53300, 110700]  Full-time          0-1 year        8 am
# 6              $              NaN  Full-time          0-1 year        8 am
#
#    minSalary  maxSalary
# 0        NaN        NaN
# 1       15.0       35.0
# 2    72000.0   182000.0
# 3        NaN        NaN
# 4        NaN        NaN
# 5    53300.0   110700.0
# 6        NaN        NaN

# %% [markdown]
# Now looking at the focus column - we have lots of focuses that are more than just one focus.

# %%
Counter(df['focus'])
# Out:
# Counter({'Frontend Developer': 82,
#          'Backend Developer': 92,
#          'Fullstack Developer': 189,
#          'UX Designer': 114,
#          'Data Analyst': 210,
#          'Data Scientist': 100,
#          'IT Support': 114,
#          'Penetration Tester': 50,
#          'Security Analyst': 155,
#          'UI Designer': 56,
#          'Outbound Sales Representative': 1,
#          'UI Designer , UX Designer': 24,
#          'Frontend Developer , Backend Developer': 2,
#          'Backend Developer , Business Analyst': 1,
#          'Fullstack Developer , Scrum': 26,
#          'Fullstack Developer , Project Management': 2,
#          'UX Designer , UX Researcher': 5,
#          'UI Designer , Scrum': 4,
#          'UI Designer , Frontend Developer': 1,
#          'UI Designer , UX Researcher , UX Designer , Product Manager': 1,
#          'UI Designer , Strategy': 1,
#          'UI Designer , UX Designer , Product Manager': 3,
#          'Data Analyst , Finance , Business Analyst': 1,
#          'Data Analyst , Business Analyst': 8,
#          'Data Analyst , Data Scientist': 34,
#          'Data Analyst , Product Manager , Data Engineer': 1,
#          'Data Analyst , Finance , Data Scientist': 1,
#          'Data Analyst , Finance': 24,
#          'Data Analyst , Strategy': 1,
#          'Data Analyst , Scrum': 2,
#          'Data Analyst , Operations Analyst': 1,
#          'Data Scientist , Data Analyst': 31,
#          'Data Scientist , Finance , Data Engineer': 1,
#          'Data Scientist , Finance': 3,
#          'Strategy , IT Support': 1,
#          'Finance , IT Support': 1,
#          'Security Analyst , Scrum': 1,
#          'Fullstack Developer , Strategy': 2,
#          'Fullstack Developer , DevOps Engineer': 1,
#          'UX Designer , Strategy': 2,
#          'Data Analyst , Data Engineer': 8,
#          'Data Scientist , Data Analyst , Finance': 4,
#          'Security Analyst , IT Support': 8,
#          'Penetration Tester , Customer Success': 1,
#          'Security Analyst , Operations Analyst': 2,
#          'Backend Developer , UX Designer , Product Manager': 1,
#          'Backend Developer , Finance , Business Analyst': 1,
#          'Fullstack Developer , UX Designer , Product Manager': 1,
#          'UX Designer , Product Manager': 2,
#          'Backend Developer , Product Manager': 1,
#          'Backend Developer , Project Management , Scrum , Data Engineer': 1,
#          'Fullstack Developer , UI Designer': 1,
#          'Fullstack Developer , IT Support': 1,
#          'Data Analyst , Customer Success , Data Engineer': 1,
#          'Data Analyst , Customer Success': 2,
#          'Data Scientist , Data Analyst , Business Analyst': 1,
#          'Data Scientist , Data Engineer': 2,
#          'IT Support , Finance': 1,
#          'Backend Developer , Fullstack Developer': 1,
#          'IT Support , Project Management': 1,
#          'Security Analyst , Project Management': 2,
#          'Security Analyst , Network Engineer': 3,
#          'Backend Developer , Frontend Developer': 1,
#          'Fullstack Developer , Strategy , Data Engineer': 5,
#          'UX Designer , UI Designer': 4,
#          'UX Designer , Customer Success': 1,
#          'Data Analyst , Finance , Data Engineer': 1,
#          'Data Analyst , Project Management': 1,
#          'Data Scientist , Strategy': 1,
#          'Data Scientist , Data Analyst , Customer Success': 1,
#          'Data Scientist , Data Analyst , Data Engineer': 1,
#          'Backend Developer , Scrum': 1,
#          'UX Designer , Product Manager , Data Scientist': 1,
#          'UX Designer , Scrum': 1,
#          'UI Designer , UX Designer , Scrum': 2,
#          'Data Analyst , Data Engineer , Data Scientist': 1,
#          'Data Scientist , Scrum': 1,
#          'Fullstack Developer , Data Engineer': 1,
#          'UX Designer , Finance': 1,
#          'Data Analyst , Strategy , Data Engineer , Data Scientist': 1,
#          'Data Analyst , Business Analyst , Data Engineer': 1,
#          'Data Scientist , Data Analyst , Strategy': 1,
#          'Data Scientist , Data Analyst , Finance , Data Engineer': 1,
#          'Penetration Tester , Security Analyst': 1,
#          'Security Analyst , Strategy': 1})

# %% [markdown]
# Jobs with multiple focuses mostly show up only once, and if we take the first focus as the focus then this should balance out and not create any major bias just by looking at the above dictionary.
#
# Se we want to put all focuses if there are multiple into a list in a new column. Then will iterate through them to replace the focus with the first focus.

# %%
#splitting the focus feature by commas so if there are more than one focus, 
#this will put them in a new column as a list, and remove white space
df['list_of_focus'] = df['focus'].str.split(',').apply(lambda x: [item.strip() for item in x])

df.head()
# Out:
#                                    company  \
# 0                                   Novovu
# 1                   Coalition Technologies
# 2  Get It Recruit - Information Technology
# 3                                     SiLo
# 4                               eDiligence
#
#                                          description                focus  \
# 0  [b]We are looking for a talented frontend web ...   Frontend Developer
# 1  [heading2]WHY YOU SHOULD APPLY:[/heading2]\r\n...   Frontend Developer
# 2  [heading2]Job Description[/heading2]\r\n\r\nAs...    Backend Developer
# 3  [b]Based in Downtown Nashville, Simple Logisti...  Fullstack Developer
# 4  [center][size=4][b]Entry Level Full Stack Deve...  Fullstack Developer
#
#                                           jobTitle  \
# 0  Frontend Developer (HTML, CSS, and JS) - Remote
# 1                              Front End Developer
# 2                Software Developer - Remote | WFH
# 3                 Junior .NET Full Stack Developer
# 4                   Entry Level Software Developer
#
#                                                 link  \
# 0  https://lensa.com/frontend-developer-html-css-...
# 1  https://www.virtualvocations.com/job/remote-fr...
# 2  https://www.linkedin.com/jobs/view/software-de...
# 3  https://jobs.wjhl.com/jobs/junior-.net-full-st...
# 4  https://jooble.org/jdp/-2571818786162603564/En...
#
#                      location            postedDate          remote  \
# 0    Fort Washington, PA, USA  Jul 14, 2023 8:00 am     100% Remote
# 1                         NaN  Jul 14, 2023 8:01 am     100% Remote
# 2  King George, VA 22485, USA  Jul 14, 2023 8:03 am  100% In-Office
# 3          Nashville, TN, USA  Jul 14, 2023 8:04 am  100% In-Office
# 4        Los Angeles, CA, USA  Jul 14, 2023 8:05 am     Hybrid Work
#
#   salaryCurrency      salaryRange       type yearsOfExperience postingHour  \
# 0              $              NaN  Full-time          0-1 year        8 am
# 1              $         [15, 35]  Full-time          0-1 year        8 am
# 2              $  [72000, 182000]  Full-time          0-1 year        8 am
# 3              $              NaN  Full-time          0-1 year        8 am
# 4              $              NaN  Full-time          0-1 year        8 am
#
#    minSalary  maxSalary          list_of_focus
# 0        NaN        NaN   [Frontend Developer]
# 1       15.0       35.0   [Frontend Developer]
# 2    72000.0   182000.0    [Backend Developer]
# 3        NaN        NaN  [Fullstack Developer]
# 4        NaN        NaN  [Fullstack Developer]

# %%
df['list_of_focus'] = df['list_of_focus'].apply(lambda x: x[0])

# %%
Counter(df['list_of_focus'])
# Out:
# Counter({'Frontend Developer': 84,
#          'Backend Developer': 100,
#          'Fullstack Developer': 229,
#          'UX Designer': 131,
#          'Data Analyst': 299,
#          'Data Scientist': 148,
#          'IT Support': 116,
#          'Penetration Tester': 52,
#          'Security Analyst': 172,
#          'UI Designer': 92,
#          'Outbound Sales Representative': 1,
#          'Strategy': 1,
#          'Finance': 1})

# %% [markdown]
# We have 3 one offs - looking at them above, Strategy and Finance have a second focus being IT support, so let's change it to that. Then, Outbound Sales doesn't have a second focus, but it is also not a tech job, so let's drop that row.

# %%
#getting the index
df[df['list_of_focus'] == 'Strategy']['list_of_focus']
# Out:
# 726    Strategy
# Name: list_of_focus, dtype: object

# %%
df[df['list_of_focus'] == 'Finance']['list_of_focus']
# Out:
# 730    Finance
# Name: list_of_focus, dtype: object

# %%
df.at[730, 'list_of_focus'] = 'IT Support'
df.at[726, 'list_of_focus'] = 'IT Support'

# %%
df[df['list_of_focus'] == 'Outbound Sales Representative']['list_of_focus']
# Out:
# 86    Outbound Sales Representative
# Name: list_of_focus, dtype: object

# %%
df.drop(86, inplace=True)

# %% [markdown]
# Double check list of focuses.

# %%
Counter(df['list_of_focus'])
# Out:
# Counter({'Frontend Developer': 84,
#          'Backend Developer': 100,
#          'Fullstack Developer': 229,
#          'UX Designer': 131,
#          'Data Analyst': 299,
#          'Data Scientist': 148,
#          'IT Support': 118,
#          'Penetration Tester': 52,
#          'Security Analyst': 172,
#          'UI Designer': 92})

# %% [markdown]
# Now that it looks good, replace the focus column with the list of focus column

# %%
df.drop(columns = 'focus', inplace = True)

# %%
df.head()
# Out:
#                                    company  \
# 0                                   Novovu
# 1                   Coalition Technologies
# 2  Get It Recruit - Information Technology
# 3                                     SiLo
# 4                               eDiligence
#
#                                          description  \
# 0  [b]We are looking for a talented frontend web ...
# 1  [heading2]WHY YOU SHOULD APPLY:[/heading2]\r\n...
# 2  [heading2]Job Description[/heading2]\r\n\r\nAs...
# 3  [b]Based in Downtown Nashville, Simple Logisti...
# 4  [center][size=4][b]Entry Level Full Stack Deve...
#
#                                           jobTitle  \
# 0  Frontend Developer (HTML, CSS, and JS) - Remote
# 1                              Front End Developer
# 2                Software Developer - Remote | WFH
# 3                 Junior .NET Full Stack Developer
# 4                   Entry Level Software Developer
#
#                                                 link  \
# 0  https://lensa.com/frontend-developer-html-css-...
# 1  https://www.virtualvocations.com/job/remote-fr...
# 2  https://www.linkedin.com/jobs/view/software-de...
# 3  https://jobs.wjhl.com/jobs/junior-.net-full-st...
# 4  https://jooble.org/jdp/-2571818786162603564/En...
#
#                      location            postedDate          remote  \
# 0    Fort Washington, PA, USA  Jul 14, 2023 8:00 am     100% Remote
# 1                         NaN  Jul 14, 2023 8:01 am     100% Remote
# 2  King George, VA 22485, USA  Jul 14, 2023 8:03 am  100% In-Office
# 3          Nashville, TN, USA  Jul 14, 2023 8:04 am  100% In-Office
# 4        Los Angeles, CA, USA  Jul 14, 2023 8:05 am     Hybrid Work
#
#   salaryCurrency      salaryRange       type yearsOfExperience postingHour  \
# 0              $              NaN  Full-time          0-1 year        8 am
# 1              $         [15, 35]  Full-time          0-1 year        8 am
# 2              $  [72000, 182000]  Full-time          0-1 year        8 am
# 3              $              NaN  Full-time          0-1 year        8 am
# 4              $              NaN  Full-time          0-1 year        8 am
#
#    minSalary  maxSalary        list_of_focus
# 0        NaN        NaN   Frontend Developer
# 1       15.0       35.0   Frontend Developer
# 2    72000.0   182000.0    Backend Developer
# 3        NaN        NaN  Fullstack Developer
# 4        NaN        NaN  Fullstack Developer

# %% [markdown]
# Now let's rename the list of focus column to just focus, but let's call it jobTitle actually, since that is really what it is. We need to remove that column now too, and let's remove the company, link, postedDate, location, salaryCurrency, and SalaryRange columns as well since we won't need them.

# %%
df.drop(columns = ['company', 'link', 'jobTitle', 'location', 'postedDate', 'salaryCurrency', 'salaryRange'], inplace = True)

# %%
df.rename(columns={'list_of_focus': 'jobTitle'}, inplace=True)

# %%
df.head()
# Out:
#                                          description          remote  \
# 0  [b]We are looking for a talented frontend web ...     100% Remote
# 1  [heading2]WHY YOU SHOULD APPLY:[/heading2]\r\n...     100% Remote
# 2  [heading2]Job Description[/heading2]\r\n\r\nAs...  100% In-Office
# 3  [b]Based in Downtown Nashville, Simple Logisti...  100% In-Office
# 4  [center][size=4][b]Entry Level Full Stack Deve...     Hybrid Work
#
#         type yearsOfExperience postingHour  minSalary  maxSalary  \
# 0  Full-time          0-1 year        8 am        NaN        NaN
# 1  Full-time          0-1 year        8 am       15.0       35.0
# 2  Full-time          0-1 year        8 am    72000.0   182000.0
# 3  Full-time          0-1 year        8 am        NaN        NaN
# 4  Full-time          0-1 year        8 am        NaN        NaN
#
#               jobTitle
# 0   Frontend Developer
# 1   Frontend Developer
# 2    Backend Developer
# 3  Fullstack Developer
# 4  Fullstack Developer

# %% [markdown]
# ## Description/Text Cleaning
#
# Now we can handle the description part.

# %%
sum(df.description.isnull())
# Out:
# 4

# %% [markdown]
# Only 4 null values, not much to worry about here.
#
# To get the skills, probably want to do some tokenization with the descriptions, grouping by jobTitle - or previously known as the focus - and the most frequent token will hopefully be the technical skills.

# %%
df.description[1]
# Out:
# "[heading2]WHY YOU SHOULD APPLY:[/heading2]\r\n\r\nCoalition Technologies is devoted to doing the highest quality of work for our clients while maintaining a fun, thriving environment for our team. Along with the opportunity to grow with our team, we are excited to offer:\r\n\r\n- The most competitive profit-sharing bonus plans in the industry. We pay up to 50% of all profits monthly to all full-time employees!\r\n- Joining our Coalition means you also get to enjoy paid time off and subsidized gym memberships.\r\n- Our US-Based team members can enjoy our medical, dental, vision, and life insurance packages in all US states.\r\n- Our international team members have the opportunity to participate in our International Insurance Reimbursement Program, a benefit unique to Coalition.\r\n\r\n100% of our team works remotely with the support of time tracking software. Our company culture has specialized in supporting remote team members for over a decade. We welcome your application, wherever in the world it's coming from!\r\n\r\n[heading2]YOU SHOULD HAVE:[/heading2]\r\n\r\n- An expertise in HTML5, CSS3 and jQuery\r\n- A thorough understanding of cross-browser compatibility issues\r\n- Experience with media queries\r\n- A knowledge of CSS platforms such as Twitter's Bootstrap\r\n- An ability to multi-task on multiple projects and tasks at the same time\r\n- Great attention to detail and be highly organized\r\n- A positive and upbeat attitude with the ability to learn quickly\r\n- Proficiency in PHP/MYSQL and AJAX (preferred)\r\n- Experience with WordPress, BigCommerce, Magento, and Shopify (preferred)\r\n- Excellent written and spoken English\r\n- The availability to work 40 hours per week from 9:00 am to 6:00 pm PST\r\n- The ability to adapt to a diverse and multicultural environment\r\n- Passion to build a startup\r\n- Reliable transportation if working in-house\r\n- A reliable workstation with a fast computer, microphone and speakers, reliable internet and power if working remotely\r\n\r\n[heading2]YOUR DUTIES AND TASKS:[/heading2]\r\n\r\n- Transforming complex layout PSDs into pixel-perfect presentation-layer HTML5/CSS3 templates\r\n- Creating responsive website designs\r\n- Building websites with WordPress, extending and developing plugins and themes\r\n- Working with Photoshop, Illustrator, and Fireworks to create images optimized for the web\r\n- Working with version control systems such as GIT / SVN\r\n- Working under tight deadlines\r\n- Handling multiple projects at the same time\r\n- Producing high quality of work with a strong focus on detail\r\n\r\nWe are looking for talented and diligent candidates who excel in our skills tests, and will consider these candidates even if past experience or educational background criteria aren't met.\r\n\r\n[heading2]Compensation:[/heading2]\r\n\r\nStarting base pay in the US states of California, New York, Washington and Colorado for this position ranges between $15 - $35 per hour"

# %% [markdown]
# grouping by job title

# %%
#filling nulls in first so next operation works
df['description'].fillna('', inplace=True)

grouped_df = df.groupby('jobTitle')['description'].apply(lambda x: ' '.join(x)).reset_index()

# %%
grouped_df
# Out:
#               jobTitle                                        description
# 0    Backend Developer  [heading2]Job Description[/heading2]\r\n\r\nAs...
# 1         Data Analyst  [center][size=4][b]Entry Level Data Analyst[/b...
# 2       Data Scientist  [heading2]Job Description[/heading2]\r\n\r\n• ...
# 3   Frontend Developer  [b]We are looking for a talented frontend web ...
# 4  Fullstack Developer  [b]Based in Downtown Nashville, Simple Logisti...
# 5           IT Support  [b]This is a remote position.[/b]\r\n\r\n[b]Wh...
# 6   Penetration Tester  [b]This a Full Remote job, the offer is availa...
# 7     Security Analyst  [b]We are thrilled to welcome a talented Junio...
# 8          UI Designer  [b]Job Description:[/b]\r\n\r\nWe are currentl...
# 9          UX Designer  [b]Job Description:[/b]\r\n\r\nWe are currentl...

# %% [markdown]
# We have a lot of text to get rid of, as seen below. anything in brackets should be replaced by spaces, and then \r and \n should be removed as well.

# %%
grouped_df.iloc[0]['description']
# Out:
# '[heading2]Job Description[/heading2]\r\n\r\nAs a full stack developer, you can resolve a problem with a complete end-to-end solution in a fast, Agile environment. If you’re looking for the chance to not just develop software, but to help create a system that will make a difference, we need you on our team. We’re looking for a developer like you with an appetite to learn and the skills needed to develop software and systems from vision to production ready.\r\n\r\nThis role is more than just coding. As a full stack developer at Booz Allen, you’ll use your passion to learn new tools and techniques and identify needed system improvements. You’ll help clients overcome their most difficult challenges using the latest architectural approaches, tools, and technologies. You’ll help make sure the solution developed by the team considers the current architecture and operating environment, as well as future functionality and enhancements.\r\n\r\nWork with us as we shape systems for the better.\r\n\r\nJoin us. The world can’t wait.\r\n\r\n[heading2]You Have[/heading2]\r\n\r\n- Experience with modern software development lifecycle techniques, including Git branching, and database driven web applications\r\n- Experience with JavaScript development in a production environment\r\n- Experience with application integration, including HTTP or REST, and database querying, including MySQL, MSSQL, or Oracle\r\n- Experience with backend development in .Net, Python, or PHP\r\n- Experience working in an Agile environment, including Demoing, Sprinting, and Iterative Development\r\n- Experience with Linux systems\r\n- Experience with code version control\r\n- Ability to obtain a security clearance\r\n- Bachelor’s degree\r\n\r\n[heading2]Nice If You Have[/heading2]\r\n\r\n- Experience in modern front-end frameworks, including React or Angular\r\n- Experience with Cloud, AWS, or Azure\r\n- Secret clearance\r\n\r\n[heading2]Clearance[/heading2]\r\n\r\nApplicants selected will be subject to a security investigation and may need to meet eligibility requirements for access to classified information.\r\n\r\n[heading2]Employment Type[/heading2]\r\n\r\nFull-Time\r\n\r\n[heading2]Salary[/heading2]\r\n\r\n$72,000.00 - $182,000.00 Per Year [center][b][size=4]Overview[/size][/b][/center]\r\n\r\nBRMi is seeking a Mid/Senior Level Backend Java Developer responsible for the development and maintenance of back-end services supporting our mobile banking apps and online banking channel. The developer will be working alongside analysts, QA testers and other Back end and Front-end engineers working on different layers of the infrastructure. Therefore, a commitment to collaborative problem solving, sophisticated design, and the creation of quality products is essential.\r\n\r\n[b]Hybrid in Vienna, VA or Pensacola, FL[/b]\r\n\r\n[b][size=4]Responsibilities[/size][/b]\r\n• Design, build, and maintain services\r\n• Ensure the performance, quality, and responsiveness of services\r\n• Collaborate with a team to define, design, and ship new features\r\n• Identify and correct bottlenecks and fix bugs\r\n• Help maintain code quality, organization, and automation\r\n• Other duties as assigned\r\n\r\n[b][size=4]Qualifications[/size][/b]\r\n• Classroom & In-Field Experience with Java 8 or greater\r\n• Good understanding of networks and how they play into applications\r\n• Understanding & Experience with Web Applications & Web Services\r\n• Experience with typical development workflows, such as building, testing, & deploying applications\r\n• Experience & solid understanding of source control such as SVN or Git\r\n• Knowledge & experience with databases, SQL, and connecting applications to them\r\n• Comfortable with troubleshooting multiple interconnected applications in an environment setting\r\n• Understand application scaling and how dependent connected services can impact performance\r\n• Has demonstrated will & ability to learn new technologies\r\n• Knowledge/experience with Spring ...

# %%
#pattern to get rid of anything in brackets
pattern = r'\[.*?\]'

grouped_df['description'] = grouped_df['description'].apply(lambda x: re.sub(pattern, '', x))
# Out:
# 'This is a   with   in brackets.'

# %%
grouped_df.iloc[0]['description']
# Out:
# 'Job Description\r\n\r\nAs a full stack developer, you can resolve a problem with a complete end-to-end solution in a fast, Agile environment. If you’re looking for the chance to not just develop software, but to help create a system that will make a difference, we need you on our team. We’re looking for a developer like you with an appetite to learn and the skills needed to develop software and systems from vision to production ready.\r\n\r\nThis role is more than just coding. As a full stack developer at Booz Allen, you’ll use your passion to learn new tools and techniques and identify needed system improvements. You’ll help clients overcome their most difficult challenges using the latest architectural approaches, tools, and technologies. You’ll help make sure the solution developed by the team considers the current architecture and operating environment, as well as future functionality and enhancements.\r\n\r\nWork with us as we shape systems for the better.\r\n\r\nJoin us. The world can’t wait.\r\n\r\nYou Have\r\n\r\n- Experience with modern software development lifecycle techniques, including Git branching, and database driven web applications\r\n- Experience with JavaScript development in a production environment\r\n- Experience with application integration, including HTTP or REST, and database querying, including MySQL, MSSQL, or Oracle\r\n- Experience with backend development in .Net, Python, or PHP\r\n- Experience working in an Agile environment, including Demoing, Sprinting, and Iterative Development\r\n- Experience with Linux systems\r\n- Experience with code version control\r\n- Ability to obtain a security clearance\r\n- Bachelor’s degree\r\n\r\nNice If You Have\r\n\r\n- Experience in modern front-end frameworks, including React or Angular\r\n- Experience with Cloud, AWS, or Azure\r\n- Secret clearance\r\n\r\nClearance\r\n\r\nApplicants selected will be subject to a security investigation and may need to meet eligibility requirements for access to classified information.\r\n\r\nEmployment Type\r\n\r\nFull-Time\r\n\r\nSalary\r\n\r\n$72,000.00 - $182,000.00 Per Year Overview\r\n\r\nBRMi is seeking a Mid/Senior Level Backend Java Developer responsible for the development and maintenance of back-end services supporting our mobile banking apps and online banking channel. The developer will be working alongside analysts, QA testers and other Back end and Front-end engineers working on different layers of the infrastructure. Therefore, a commitment to collaborative problem solving, sophisticated design, and the creation of quality products is essential.\r\n\r\nHybrid in Vienna, VA or Pensacola, FL\r\n\r\nResponsibilities\r\n• Design, build, and maintain services\r\n• Ensure the performance, quality, and responsiveness of services\r\n• Collaborate with a team to define, design, and ship new features\r\n• Identify and correct bottlenecks and fix bugs\r\n• Help maintain code quality, organization, and automation\r\n• Other duties as assigned\r\n\r\nQualifications\r\n• Classroom & In-Field Experience with Java 8 or greater\r\n• Good understanding of networks and how they play into applications\r\n• Understanding & Experience with Web Applications & Web Services\r\n• Experience with typical development workflows, such as building, testing, & deploying applications\r\n• Experience & solid understanding of source control such as SVN or Git\r\n• Knowledge & experience with databases, SQL, and connecting applications to them\r\n• Comfortable with troubleshooting multiple interconnected applications in an environment setting\r\n• Understand application scaling and how dependent connected services can impact performance\r\n• Has demonstrated will & ability to learn new technologies\r\n• Knowledge/experience with Spring/Spring Boot\r\n• Experience with Micro Service Architectures\r\n• Experience with developing Cloud applications/systems\r\n• Experience working in Agile environment\r\n• *** BRMi will not sponsor applicants for work ...

# %% [markdown]
# quickly scanning this it seems it is just punctuations and \r and \n that need to be removed now.

# %%
grouped_df['description'] = grouped_df['description'].apply(lambda x: x.replace('\r', ' '))
grouped_df['description'] = grouped_df['description'].apply(lambda x: x.replace('\n', ' '))

# %% [markdown]
# Now just punctuations.

# %%
punctuation_list = list(string.punctuation)

for punc in punctuation_list:
    grouped_df['description'] = grouped_df['description'].apply(lambda x: x.replace(punc, ' '))

# %%
grouped_df.iloc[0]['description']
# Out:
# 'Job Description    As a full stack developer  you can resolve a problem with a complete end to end solution in a fast  Agile environment  If you’re looking for the chance to not just develop software  but to help create a system that will make a difference  we need you on our team  We’re looking for a developer like you with an appetite to learn and the skills needed to develop software and systems from vision to production ready     This role is more than just coding  As a full stack developer at Booz Allen  you’ll use your passion to learn new tools and techniques and identify needed system improvements  You’ll help clients overcome their most difficult challenges using the latest architectural approaches  tools  and technologies  You’ll help make sure the solution developed by the team considers the current architecture and operating environment  as well as future functionality and enhancements     Work with us as we shape systems for the better     Join us  The world can’t wait     You Have      Experience with modern software development lifecycle techniques  including Git branching  and database driven web applications    Experience with JavaScript development in a production environment    Experience with application integration  including HTTP or REST  and database querying  including MySQL  MSSQL  or Oracle    Experience with backend development in  Net  Python  or PHP    Experience working in an Agile environment  including Demoing  Sprinting  and Iterative Development    Experience with Linux systems    Experience with code version control    Ability to obtain a security clearance    Bachelor’s degree    Nice If You Have      Experience in modern front end frameworks  including React or Angular    Experience with Cloud  AWS  or Azure    Secret clearance    Clearance    Applicants selected will be subject to a security investigation and may need to meet eligibility requirements for access to classified information     Employment Type    Full Time    Salary     72 000 00    182 000 00 Per Year Overview    BRMi is seeking a Mid Senior Level Backend Java Developer responsible for the development and maintenance of back end services supporting our mobile banking apps and online banking channel  The developer will be working alongside analysts  QA testers and other Back end and Front end engineers working on different layers of the infrastructure  Therefore  a commitment to collaborative problem solving  sophisticated design  and the creation of quality products is essential     Hybrid in Vienna  VA or Pensacola  FL    Responsibilities  • Design  build  and maintain services  • Ensure the performance  quality  and responsiveness of services  • Collaborate with a team to define  design  and ship new features  • Identify and correct bottlenecks and fix bugs  • Help maintain code quality  organization  and automation  • Other duties as assigned    Qualifications  • Classroom   In Field Experience with Java 8 or greater  • Good understanding of networks and how they play into applications  • Understanding   Experience with Web Applications   Web Services  • Experience with typical development workflows  such as building  testing    deploying applications  • Experience   solid understanding of source control such as SVN or Git  • Knowledge   experience with databases  SQL  and connecting applications to them  • Comfortable with troubleshooting multiple interconnected applications in an environment setting  • Understand application scaling and how dependent connected services can impact performance  • Has demonstrated will   ability to learn new technologies  • Knowledge experience with Spring Spring Boot  • Experience with Micro Service Architectures  • Experience with developing Cloud applications systems  • Experience working in Agile environment  •     BRMi will not sponsor applicants for work visas for this position         This is a W2 opportunity only    EOE Minorities Females Vet Disabled    We are an equal opportunity ...

# %% [markdown]
# One more time, bullet points weren't in the punctuation list so we need to do that too.

# %%
grouped_df['description'] = grouped_df['description'].apply(lambda x: x.replace('•', ' '))

# %%
grouped_df.iloc[0]['description']
# Out:
# 'Job Description    As a full stack developer  you can resolve a problem with a complete end to end solution in a fast  Agile environment  If you’re looking for the chance to not just develop software  but to help create a system that will make a difference  we need you on our team  We’re looking for a developer like you with an appetite to learn and the skills needed to develop software and systems from vision to production ready     This role is more than just coding  As a full stack developer at Booz Allen  you’ll use your passion to learn new tools and techniques and identify needed system improvements  You’ll help clients overcome their most difficult challenges using the latest architectural approaches  tools  and technologies  You’ll help make sure the solution developed by the team considers the current architecture and operating environment  as well as future functionality and enhancements     Work with us as we shape systems for the better     Join us  The world can’t wait     You Have      Experience with modern software development lifecycle techniques  including Git branching  and database driven web applications    Experience with JavaScript development in a production environment    Experience with application integration  including HTTP or REST  and database querying  including MySQL  MSSQL  or Oracle    Experience with backend development in  Net  Python  or PHP    Experience working in an Agile environment  including Demoing  Sprinting  and Iterative Development    Experience with Linux systems    Experience with code version control    Ability to obtain a security clearance    Bachelor’s degree    Nice If You Have      Experience in modern front end frameworks  including React or Angular    Experience with Cloud  AWS  or Azure    Secret clearance    Clearance    Applicants selected will be subject to a security investigation and may need to meet eligibility requirements for access to classified information     Employment Type    Full Time    Salary     72 000 00    182 000 00 Per Year Overview    BRMi is seeking a Mid Senior Level Backend Java Developer responsible for the development and maintenance of back end services supporting our mobile banking apps and online banking channel  The developer will be working alongside analysts  QA testers and other Back end and Front end engineers working on different layers of the infrastructure  Therefore  a commitment to collaborative problem solving  sophisticated design  and the creation of quality products is essential     Hybrid in Vienna  VA or Pensacola  FL    Responsibilities    Design  build  and maintain services    Ensure the performance  quality  and responsiveness of services    Collaborate with a team to define  design  and ship new features    Identify and correct bottlenecks and fix bugs    Help maintain code quality  organization  and automation    Other duties as assigned    Qualifications    Classroom   In Field Experience with Java 8 or greater    Good understanding of networks and how they play into applications    Understanding   Experience with Web Applications   Web Services    Experience with typical development workflows  such as building  testing    deploying applications    Experience   solid understanding of source control such as SVN or Git    Knowledge   experience with databases  SQL  and connecting applications to them    Comfortable with troubleshooting multiple interconnected applications in an environment setting    Understand application scaling and how dependent connected services can impact performance    Has demonstrated will   ability to learn new technologies    Knowledge experience with Spring Spring Boot    Experience with Micro Service Architectures    Experience with developing Cloud applications systems    Experience working in Agile environment        BRMi will not sponsor applicants for work visas for this position         This is a W2 opportunity only    EOE Minorities Females Vet Disabled    We are an equal opportunity ...

# %% [markdown]
# removing extra spaces

# %%
grouped_df['description'] = grouped_df['description'].apply(lambda x: x.split())
grouped_df['description'] = grouped_df['description'].apply(lambda x: ' '.join(x))

grouped_df.iloc[0]['description']
# Out:
# 'Job Description As a full stack developer you can resolve a problem with a complete end to end solution in a fast Agile environment If you’re looking for the chance to not just develop software but to help create a system that will make a difference we need you on our team We’re looking for a developer like you with an appetite to learn and the skills needed to develop software and systems from vision to production ready This role is more than just coding As a full stack developer at Booz Allen you’ll use your passion to learn new tools and techniques and identify needed system improvements You’ll help clients overcome their most difficult challenges using the latest architectural approaches tools and technologies You’ll help make sure the solution developed by the team considers the current architecture and operating environment as well as future functionality and enhancements Work with us as we shape systems for the better Join us The world can’t wait You Have Experience with modern software development lifecycle techniques including Git branching and database driven web applications Experience with JavaScript development in a production environment Experience with application integration including HTTP or REST and database querying including MySQL MSSQL or Oracle Experience with backend development in Net Python or PHP Experience working in an Agile environment including Demoing Sprinting and Iterative Development Experience with Linux systems Experience with code version control Ability to obtain a security clearance Bachelor’s degree Nice If You Have Experience in modern front end frameworks including React or Angular Experience with Cloud AWS or Azure Secret clearance Clearance Applicants selected will be subject to a security investigation and may need to meet eligibility requirements for access to classified information Employment Type Full Time Salary 72 000 00 182 000 00 Per Year Overview BRMi is seeking a Mid Senior Level Backend Java Developer responsible for the development and maintenance of back end services supporting our mobile banking apps and online banking channel The developer will be working alongside analysts QA testers and other Back end and Front end engineers working on different layers of the infrastructure Therefore a commitment to collaborative problem solving sophisticated design and the creation of quality products is essential Hybrid in Vienna VA or Pensacola FL Responsibilities Design build and maintain services Ensure the performance quality and responsiveness of services Collaborate with a team to define design and ship new features Identify and correct bottlenecks and fix bugs Help maintain code quality organization and automation Other duties as assigned Qualifications Classroom In Field Experience with Java 8 or greater Good understanding of networks and how they play into applications Understanding Experience with Web Applications Web Services Experience with typical development workflows such as building testing deploying applications Experience solid understanding of source control such as SVN or Git Knowledge experience with databases SQL and connecting applications to them Comfortable with troubleshooting multiple interconnected applications in an environment setting Understand application scaling and how dependent connected services can impact performance Has demonstrated will ability to learn new technologies Knowledge experience with Spring Spring Boot Experience with Micro Service Architectures Experience with developing Cloud applications systems Experience working in Agile environment BRMi will not sponsor applicants for work visas for this position This is a W2 opportunity only EOE Minorities Females Vet Disabled We are an equal opportunity employer that values diversity and commitment at all levels All individuals regardless of personal characteristics are encouraged to apply Employment policies and decisions on employment and promotion are based on merit qualifications perfo ...

# %%
#let's also lower case everything now
grouped_df['description'] = grouped_df['description'].apply(lambda x: x.lower())

#grouped_df.iloc[0]['description']
# Out:
# 'job description as a full stack developer you can resolve a problem with a complete end to end solution in a fast agile environment if you’re looking for the chance to not just develop software but to help create a system that will make a difference we need you on our team we’re looking for a developer like you with an appetite to learn and the skills needed to develop software and systems from vision to production ready this role is more than just coding as a full stack developer at booz allen you’ll use your passion to learn new tools and techniques and identify needed system improvements you’ll help clients overcome their most difficult challenges using the latest architectural approaches tools and technologies you’ll help make sure the solution developed by the team considers the current architecture and operating environment as well as future functionality and enhancements work with us as we shape systems for the better join us the world can’t wait you have experience with modern software development lifecycle techniques including git branching and database driven web applications experience with javascript development in a production environment experience with application integration including http or rest and database querying including mysql mssql or oracle experience with backend development in net python or php experience working in an agile environment including demoing sprinting and iterative development experience with linux systems experience with code version control ability to obtain a security clearance bachelor’s degree nice if you have experience in modern front end frameworks including react or angular experience with cloud aws or azure secret clearance clearance applicants selected will be subject to a security investigation and may need to meet eligibility requirements for access to classified information employment type full time salary 72 000 00 182 000 00 per year overview brmi is seeking a mid senior level backend java developer responsible for the development and maintenance of back end services supporting our mobile banking apps and online banking channel the developer will be working alongside analysts qa testers and other back end and front end engineers working on different layers of the infrastructure therefore a commitment to collaborative problem solving sophisticated design and the creation of quality products is essential hybrid in vienna va or pensacola fl responsibilities design build and maintain services ensure the performance quality and responsiveness of services collaborate with a team to define design and ship new features identify and correct bottlenecks and fix bugs help maintain code quality organization and automation other duties as assigned qualifications classroom in field experience with java 8 or greater good understanding of networks and how they play into applications understanding experience with web applications web services experience with typical development workflows such as building testing deploying applications experience solid understanding of source control such as svn or git knowledge experience with databases sql and connecting applications to them comfortable with troubleshooting multiple interconnected applications in an environment setting understand application scaling and how dependent connected services can impact performance has demonstrated will ability to learn new technologies knowledge experience with spring spring boot experience with micro service architectures experience with developing cloud applications systems experience working in agile environment brmi will not sponsor applicants for work visas for this position this is a w2 opportunity only eoe minorities females vet disabled we are an equal opportunity employer that values diversity and commitment at all levels all individuals regardless of personal characteristics are encouraged to apply employment policies and decisions on employment and promotion are based on merit qualifications perfo ...

# %% [markdown]
# Now let's remove stop words.

# %%
nltk.download('stopwords')
#set of stopwords to search through
stop_words = set(stopwords.words('english'))

#tokenize and then remove stop words 
grouped_df['description'] = grouped_df['description'].apply(lambda x: nltk.word_tokenize(x))
grouped_df['description'] = grouped_df['description'].apply(lambda x: [word for word in x if word not in stop_words])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\RaviB\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Easiest thing to do here since hard technical skills aren't the most common is to look manually for the top 5 of each one, and note them down in another dictinary of dataframe.

# %%
Counter(grouped_df.iloc[0]['description']).most_common()
# Out:
# [('experience', 550),
#  ('team', 279),
#  ('work', 249),
#  ('data', 220),
#  ('development', 218),
#  ('backend', 204),
#  ('working', 183),
#  ('’', 169),
#  ('software', 159),
#  ('skills', 144),
#  ('services', 137),
#  ('design', 136),
#  ('applications', 133),
#  ('web', 131),
#  ('code', 125),
#  ('new', 116),
#  ('developer', 115),
#  ('end', 114),
#  ('technologies', 113),
#  ('cloud', 109),
#  ('knowledge', 109),
#  ('ability', 107),
#  ('us', 106),
#  ('strong', 106),
#  ('role', 105),
#  ('systems', 103),
#  ('job', 100),
#  ('solutions', 100),
#  ('using', 97),
#  ('requirements', 97),
#  ('engineering', 97),
#  ('application', 95),
#  ('opportunity', 95),
#  ('environment', 93),
#  ('years', 93),
#  ('including', 89),
#  ('time', 89),
#  ('building', 89),
#  ('product', 89),
#  ('business', 85),
#  ('technical', 85),
#  ('build', 84),
#  ('company', 84),
#  ('quality', 81),
#  ('help', 79),
#  ('engineers', 76),
#  ('understanding', 74),
#  ('position', 72),
#  ('technology', 72),
#  ('teams', 72),
#  ('engineer', 69),
#  ('back', 68),
#  ('status', 68),
#  ('employment', 67),
#  ('java', 67),
#  ('full', 66),
#  ('tools', 66),
#  ('information', 66),
#  ('high', 66),
#  ('collaborate', 65),
#  ('join', 64),
#  ('aws', 63),
#  ('remote', 63),
#  ('scalable', 63),
#  ('like', 62),
#  ('responsibilities', 62),
#  ('maintain', 62),
#  ('benefits', 62),
#  ('looking', 60),
#  ('infrastructure', 60),
#  ('required', 60),
#  ('apis', 60),
#  ('python', 59),
#  ('equal', 59),
#  ('platform', 59),
#  ('stack', 58),
#  ('well', 58),
#  ('computer', 58),
#  ('user', 58),
#  ('features', 57),
#  ('based', 57),
#  ('health', 57),
#  ('degree', 56),
#  ('develop', 54),
#  ('ensure', 54),
#  ('support', 54),
#  ('best', 54),
#  ('performance', 53),
#  ('problem', 52),
#  ('000', 51),
#  ('disability', 51),
#  ('3', 51),
#  ('communication', 51),
#  ('professional', 50),
#  ('familiarity', 50),
#  ('products', 49),
#  ('practices', 49),
#  ('·', 49),
#  ('react', 48),
#  ('employer', 48),
#  ('related', 48),
#  ('frontend', 48),
#  ('javascript', 47),
#  ('qualifications', 47),
#  ('developing', 47),
#  ('national', 47),
#  ('science', 47),
#  ('learning', 47),
#  ('projects', 47),
#  ('solving', 46),
#  ('gender', 46),
#  ('project', 46),
#  ('zapier', 46),
#  ('architecture', 45),
#  ('process', 45),
#  ('2', 45),
#  ('api', 45),
#  ('part', 45),
#  ('university', 45),
#  ('agile', 44),
#  ('level', 44),
#  ('apply', 44),
#  ('race', 43),
#  ('religion', 43),
#  ('implement', 43),
#  ('fast', 42),
#  ('make', 42),
#  ('learn', 42),
#  ('impact', 42),
#  ('across', 42),
#  ('plus', 42),
#  ('testing', 41),
#  ('veteran', 41),
#  ('orientation', 41),
#  ('programming', 41),
#  ('docker', 41),
#  ('world', 40),
#  ('without', 40),
#  ('e', 40),
#  ('also', 40),
#  ('management', 40),
#  ('industry', 40),
#  ('js', 40),
#  ('within', 40),
#  ('databases', 39),
#  ('complex', 39),
#  ('customers', 39),
#  ('improve', 39),
#  ('front', 38),
#  ('good', 38),
#  ('origin', 38),
#  ('1', 38),
#  ('sexual', 38),
#  ('preferred', 38),
#  ('please', 38),
#  ('provide', 38),
#  ('ai', 38),
#  ('growing', 38),
#  ('pay', 38),
#  ('bachelor', 37),
#  ('color', 37),
#  ('edge', 37),
#  ('creating', 37),
#  ('hands', 37),
#  ('take', 37),
#  ('contribute', 37),
#  ('database', 36),
#  ('frameworks', 36),
#  ('applicants', 36),
#  ('needs', 36),
#  ('employees', 36),
#  ('must', 36),
#  ('languages', 36),
#  ('salary', 35),
#  ('platforms', 35),
#  ('problems', 35),
#  ('developers', 35),
#  ('vision', 34),
#  ('junior', 34),
#  ('talented', 34),
#  ('typescript', 34),
#  ('functional', 34),
#  ('excellent', 34),
#  ('one', 34),
#  ('description', 33),
#  ('control', 33),
#  ('collaborative', 33),
#  ('field', 33),
#  ('age', 33),
#  ('identity', 33),
#  ('protected', 33),
#  ('customer', 33),
#  ('compensation', 33),
#  ('paid', 33),
#  ('core', 33),
#  ('security', 32),
#  ('regard', 32),
#  ('sex', 32),
#  ('expertise', 32),
#  ('enhance', 32),
#  ('deliver', 32),
#  ('system', 31),
#  ('production', 31),
#  ('sql', 31),
#  ('insurance', 31),
#  ('growth', 31),
#  ('people', 31),
#  ('range', 31),
#  ('issues', 31),
#  ('create', 30),
#  ('git', 30),
#  ('rest', 30),
#  ('include', 30),
#  ('cross', 30),
#  ('proficiency', 30),
#  ('existing', 30),
#  ('lead', 30),
#  ('need', 29),
#  ('html', 29),
#  ('candidate', 29),
#  ('css', 29),
#  ('c', 29),
#  ('scale', 29),
#  ('location', 28),
#  ('research', 28),
#  ('success', 28),
#  ('mission', 28),
#  ('experiences', 28),
#  ('effectively', 28),
#  ('opportunities', 28),
#  ('great', 28),
#  ('test', 28),
#  ('passion', 27),
#  ('azure', 27),
#  ('state', 27),
#  ('education', 27),
#  ('etc', 27),
#  ('node', 27),
#  ('client', 27),
#  ('video', 27),
#  ('base', 27),
#  ('coding', 26),
#  ('use', 26),
#  ('driven', 26),
#  ('may', 26),
#  ('understand', 26),
#  ('global', 26),
#  ('analysis', 26),
#  ('competitive', 26),
#  ('restful', 26),
#  ('maintaining', 26),
#  ('diverse', 26),
#  ('individual', 26),
#  ('closely', 26),
#  ('get', 26),
#  ('written', 26),
#  ('go', 26),
#  ('modern', 25),
#  ('responsible', 25),
#  ('different', 25),
#  ('healthcare', 25),
#  ('innovative', 25),
#  ('group', 25),
#  ('collaboration', 25),
#  ('implementing', 25),
#  ('highly', 25),
#  ('future', 24),
#  ('organization', 24),
#  ('service', 24),
#  ('career', 24),
#  ('ci', 24),
#  ('law', 24),
#  ('offer', 24),
#  ('flexible', 24),
#  ('processing', 24),
#  ('writing', 24),
#  ('robust', 24),
#  ('processes', 24),
#  ('available', 24),
#  ('designing', 24),
#  ('companies', 24),
#  ('write', 24),
#  ('users', 24),
#  ('minimum', 24),
#  ('principles', 24),
#  ('tech', 24),
#  ('things', 24),
#  ('access', 23),
#  ('mobile', 23),
#  ('diversity', 23),
#  ('passionate', 23),
#  ('love', 23),
#  ('standards', 23),
#  ('want', 23),
#  ('equivalent', 23),
#  ('members', 23),
#  ('grow', 23),
#  ('drive', 23),
#  ('deployment', 23),
#  ('functionality', 22),
#  ('meet', 22),
#  ('equity', 22),
#  ('able', 22),
#  ('committed', 22),
#  ('com', 22),
#  ('cutting', 22),
#  ('participate', 22),
#  ('relevant', 22),
#  ('websites', 22),
#  ('every', 22),
#  ('open', 22),
#  ('relational', 22),
#  ('day', 22),
#  ('stakeholders', 22),
#  ('know', 22),
#  ('power', 22),
#  ('better', 21),
#  ('year', 21),
#  ('seeking', 21),
#  ('medical', 21),
#  ('delivering', 21),
#  ('solve', 21),
#  ('focus', 21),
#  ('qualified', 21),
#  ('programs', 21),
#  ('efficient', 21),
#  ('candidates', 21),
#  ('works', 21),
#  ('supporting', 20),
#  ('solid', 20),
#  ('spring', 20),
#  ('operations', 20),
#  ('receive', 20),
#  ('believe', 20),
#  ('functions', 20),
#  ('large', 20),
#  ('culture', 20),
#  ('oriented', 20),
#  ('components', 20),
#  ('area', 20),
#  ('similar', 20),
#  ('first', 20),
#  ('amplemarket', 20),
#  ('latest', 19),
#  ('php', 19),
#  ('version', 19),
#  ('source', 19),
#  ('comfortable', 19),
#  ('values', 19),
#  ('decisions', 19),
#  ('local', 19),
#  ('date', 19),
#  ('department', 19),
#  ('consideration', 19),
#  ('package', 19),
#  ('office', 19),
#  ('reviews', 19),
#  ('self', 19),
#  ('rapidly', 19),
#  ('digital', 19),
#  ('bring', 19),
#  ('fully', 19),
#  ('provides', 19),
#  ('cd', 19),
#  ('chicago', 19),
#  ('g', 19),
#  ('u', 19),
#  ('type', 18),
#  ('online', 18),
#  ('ship', 18),
#  ('duties', 18),
#  ('play', 18),
#  ('multiple', 18),
#  ('individuals', 18),
#  ('federal', 18),
#  ('critical', 18),
#  ('dental', 18),
#  ('delivery', 18),
#  ('exceptional', 18),
#  ('life', 18),
#  ('ensuring', 18),
#  ('dynamic', 18),
#  ('–', 18),
#  ('server', 18),
#  ('verbal', 18),
#  ('see', 18),
#  ('basis', 18),
#  ('member', 18),
#  ('applicable', 18),
#  ('sales', 18),
#  ('clients', 17),
#  ('integration', 17),
#  ('apps', 17),
#  ('commitment', 17),
#  ('define', 17),
#  ('automation', 17),
#  ('patterns', 17),
#  ('proven', 17),
#  ('continuous', 17),
#  ('would', 17),
#  ('inclusive', 17),
#  ('plan', 17),
#  ('responsive', 17),
#  ('integrate', 17),
#  ('optimization', 17),
#  ('framework', 17),
#  ('value', 17),
#  ('various', 17),
#  ('paced', 17),
#  ('ownership', 17),
#  ('internal', 17),
#  ('golang', 17),
#  ('making', 17),
#  ('implementation', 17),
#  ('eligible', 17),
#  ('party', 17),
#  ('millions', 17),
#  ('identify', 16),
#  ('per', 16),
#  ('maintenance', 16),
#  ('start', 16),
#  ('require', 16),
#  ('employee', 16),
#  ('via', 16),
#  ('proficient', 16),
#  ('google', 16),
#  ('ideas', 16),
#  ('motivated', 16),
#  ('redis', 16),
#  ('activities', 16),
#  ('manage', 16),
#  ('concepts', 16),
#  ('django', 16),
#  ('content', 16),
#  ('includes', 16),
#  ('clinical', 16),
#  ('experienced', 16),
#  ('automated', 16),
#  ('tests', 16),
#  ('sports', 16),
#  ('needed', 15),
#  ('challenges', 15),
#  ('mysql', 15),
#  ('demonstrated', 15),
#  ('primary', 15),
#  ('small', 15),
#  ('three', 15),
#  ('united', 15),
#  ('maintainable', 15),
#  ('5', 15),
#  ('genetic', 15),
#  ('next', 15),
#  ('managing', 15),
#  ('stay', 15),
#  ('kubernetes', 15),
#  ('tasks', 15),
#  ('share', 15),
#  ('others', 15),
#  ('unique', 15),
#  ('interfaces', 15),
#  ('designers', 15),
#  ('thrive', 15),
#  ('questions', 15),
#  ('effective', 15),
#  ('comprehensive', 15),
#  ('providing', 15),
#  ('distributed', 15),
#  ('basic', 15),
#  ('app', 15),
#  ('potential', 15),
#  ('hours', 15),
#  ('additional', 15),
#  ('offers', 15),
#  ('communicate', 15),
#  ('care', 15),
#  ('feedback', 15),
#  ('debugging', 15),
#  ('built', 15),
#  ('innovation', 15),
#  ('ford', 15),
#  ('workflows', 14),
#  ('staff', 14),
#  ('states', 14),
#  ('deep', 14),
#  ('long', 14),
#  ('term', 14),
#  ('analytics', 14),
#  ('fit', 14),
#  ('planning', 14),
#  ('daily', 14),
#  ('appropriate', 14),
#  ('following', 14),
#  ('reasonable', 14),
#  ('review', 14),
#  ('seamless', 14),
#  ('least', 14),
#  ('together', 14),
#  ('leading', 14),
#  ('detail', 14),
#  ('quickly', 14),
#  ('week', 14),
#  ('scraping', 14),
#  ('report', 14),
#  ('gcp', 14),
#  ('key', 14),
#  ('clean', 14),
#  ('ux', 14),
#  ('net', 13),
#  ('senior', 13),
#  ('personal', 13),
#  ('physical', 13),
#  ('locations', 13),
#  ('training', 13),
#  ('community', 13),
#  ('inclusion', 13),
#  ('standard', 13),
#  ('simple', 13),
#  ('way', 13),
#  ('scalability', 13),
#  ('nosql', 13),
#  ('real', 13),
#  ('program', 13),
#  ('https', 13),
#  ('family', 13),
#  ('express', 13),
#  ('independently', 13),
#  ('changing', 13),
#  ('microsoft', 13),
#  ('areas', 13),
#  ('capabilities', 13),
#  ('non', 13),
#  ('common', 13),
#  ('serve', 13),
#  ('queries', 13),
#  ('conviction', 13),
#  ('deploy', 13),
#  ('think', 13),
#  ('troubleshoot', 13),
#  ('used', 13),
#  ('ui', 13),
#  ('everyday', 13),
#  ('techniques', 12),
#  ('current', 12),
#  ('assigned', 12),
#  ('troubleshooting', 12),
#  ('regardless', 12),
#  ('marital', 12),
#  ('days', 12),
#  ('spectrum', 12),
#  ('eeo', 12),
#  ('devops', 12),
#  ('terraform', 12),
#  ('native', 12),
#  ('forward', 12),
#  ('leverage', 12),
#  ('objectives', 12),
#  ('storage', 12),
#  ('designs', 12),
#  ('startup', 12),
#  ('financial', 12),
#  ('welcome', 12),
#  ('set', 12),
#  ('leadership', 12),
#  ('github', 12),
#  ('environments', 12),
#  ('match', 12),
#  ('responsibility', 12),
#  ('braintrust', 12),
#  ('keep', 12),
#  ('mongodb', 12),
#  ('machine', 12),
#  ('record', 12),
#  ('familiar', 12),
#  ('pediatric', 12),
#  ('cancer', 12),
#  ('commons', 12),
#  ('d4cg', 12),
#  ('addition', 12),
#  ('requests', 12),
#  ('call', 12),
#  ('plans', 12),
#  ('find', 12),
#  ('thinking', 12),
#  ('reliable', 12),
#  ('duetti', 12),
#  ('artists', 12),
#  ('master', 12),
#  ('trends', 12),
#  ('directly', 12),
#  ('architect', 12),
#  ('interview', 12),
#  ('linux', 11),
#  ('nice', 11),
#  ('angular', 11),
#  ('qa', 11),
#  ('hybrid', 11),
#  ('bugs', 11),
#  ('disabled', 11),
#  ('2023', 11),
#  ('intelligence', 11),
#  ('throughout', 11),
#  ('strive', 11),
#  ('enabling', 11),
#  ('hear', 11),
#  ('accommodation', 11),
#  ('request', 11),
#  ('approach', 11),
#  ('businesses', 11),
#  ('big', 11),
#  ('background', 11),
#  ('401', 11),
#  ('k', 11),
#  ('action', 11),
#  ('jobs', 11),
#  ('top', 11),
#  ('embrace', 11),
#  ('roles', 11),
#  ('assist', 11),
#  ('enjoy', 11),
#  ('goals', 11),
#  ('come', 11),
#  ('balance', 11),
#  ('sense', 11),
#  ('helps', 11),
#  ('computing', 11),
#  ('advanced', 11),
#  ('change', 11),
#  ('facing', 11),
#  ('details', 11),
#  ('resume', 11),
#  ('track', 11),
#  ('cell', 11),
#  ('enable', 11),
#  ('leveraging', 11),
#  ('wide', 11),
#  ('summary', 11),
#  ('performing', 11),
#  ('upon', 11),
#  ('conduct', 11),
#  ('mentor', 11),
#  ('lives', 11),
#  ('partners', 11),
#  ('helping', 11),
#  ('true', 11),
#  ('exciting', 11),
#  ('guide', 11),
#  ('http', 10),
#  ('00', 10),
#  ('alongside', 10),
#  ('greater', 10),
#  ('deploying', 10),
#  ('made', 10),
#  ('travel', 10),
#  ('founded', 10),
#  ('holidays', 10),
#  ('limited', 10),
#  ('lambda', 10),
#  ('prior', 10),
#  ('algorithms', 10),
#  ('low', 10),
#  ('primarily', 10),
#  ('handle', 10),
#  ('specific', 10),
#  ('website', 10),
#  ('outcomes', 10),
#  ('www', 10),
#  ('assistance', 10),
#  ('optimize', 10),
#  ('desire', 10),
#  ('home', 10),
#  ('english', 10),
#  ('mindset', 10),
#  ('always', 10),
#  ('become', 10),
#  ('person', 10),
#  ('logic', 10),
#  ('postgresql', 10),
#  ('today', 10),
#  ('100', 10),
#  ('seek', 10),
#  ('utilizing', 10),
#  ('competencies', 10),
#  ('place', 10),
#  ('unit', 10),
#  ('flask', 10),
#  ('documents', 10),
#  ('leave', 10),
#  ('4', 10),
#  ('secure', 10),
#  ('site', 10),
#  ('third', 10),
#  ('methodologies', 10),
#  ('proactive', 10),
#  ('willingness', 10),
#  ('models', 10),
#  ('managers', 10),
#  ('monitor', 10),
#  ('integrating', 10),
#  ('encourage', 10),
#  ('wisdomtree', 10),
#  ('b2b', 10),
#  ('mid', 9),
#  ('setting', 9),
#  ('scaling', 9),
#  ('boot', 9),
#  ('mental', 9),
#  ('7', 9),
#  ('york', 9),
#  ('foster', 9),
#  ('sqs', 9),
#  ('s3', 9),
#  ('enterprise', 9),
#  ('consistent', 9),
#  ('dedicated', 9),
#  ('empower', 9),
#  ('pivotal', 9),
#  ('elasticsearch', 9),
#  ('address', 9),
#  ('co', 9),
#  ('powered', 9),
#  ('excited', 9),
#  ('vue', 9),
#  ('interest', 9),
#  ('perks', 9),
#  ('options', 9),
#  ('expected', 9),
#  ('ecommerce', 9),
#  ('workflow', 9),
#  ('line', 9),
#  ('credit', 9),
#  ('efforts', 9),
#  ('focused', 9),
#  ('immediate', 9),
#  ('hiring', 9),
#  ('c2c', 9),
#  ('anywhere', 9),
#  ('form', 9),
#  ('goal', 9),
#  ('makes', 9),
#  ('handling', 9),
#  ('around', 9),
#  ('perspectives', 9),
#  ('currently', 9),
#  ('object', 9),
#  ('external', 9),
#  ('rare', 9),
#  ('guidance', 9),
#  ('amazon', 9),
#  ('inquiry', 9),
#  ('challenge', 9),
#  ('exchange', 9),
#  ('safety', 9),
#  ('class', 9),
#  ('kafka', 9),
#  ('cigna', 9),
#  ('analytical', 9),
#  ('libraries', 9),
#  ('organizational', 9),
#  ('factors', 9),
#  ('laws', 9),
#  ('possible', 9),
#  ('codebase', 9),
#  ('creative', 9),
#  ('serverless', 9),
#  ('everything', 9),
#  ('microservices', 9),
#  ('major', 9),
#  ('graphql', 9),
#  ('significant', 9),
#  ('b', 9),
#  ('achieve', 9),
#  ('market', 9),
#  ('saas', 9),
#  ('backed', 9),
#  ('red', 9),
#  ('assets', 9),
#  ('solution', 8),
#  ('ready', 8),
#  ('shape', 8),
#  ('subject', 8),
#  ('overview', 8),
#  ('analysts', 8),
#  ('essential', 8),
#  ('fix', 8),
#  ('8', 8),
#  ('determined', 8),
#  ('characteristic', 8),
#  ('jenkins', 8),
#  ('abilities', 8),
#  ('scrum', 8),
#  ('structures', 8),
#  ('read', 8),
#  ('policy', 8),
#  ('discriminate', 8),
#  ('successful', 8),
#  ('execute', 8),
#  ('proactively', 8),
#  ('containerization', 8),
#  ('affirmative', 8),
#  ('reusable', 8),
#  ('add', 8),
#  ('extra', 8),
#  ('sets', 8),
#  ('demonstrate', 8),
#  ('benefit', 8),
#  ('coverage', 8),
#  ('tuning', 8),
#  ('attention', 8),
#  ('expert', 8),
#  ('contributing', 8),
#  ('live', 8),
#  ('extensive', 8),
#  ('someone', 8),
#  ('page', 8),
#  ('side', 8),
#  ('debug', 8),
#  ('llc', 8),
#  ('kotlin', 8),
#  ('interested', 8),
#  ('initiative', 8),
#  ('gather', 8),
#  ('analyze', 8),
#  ('performs', 8),
#  ('3rd', 8),
#  ('oop', 8),
#  ('monthly', 8),
#  ('check', 8),
#  ('nature', 8),
#  ('annual', 8),
#  ('offices', 8),
#  ('flexibility', 8),
#  ('independent', 8),
#  ('bonus', 8),
#  ('right', 8),
#  ('ideal', 8),
#  ('releases', 8),
#  ('servers', 8),
#  ('constructive', 8),
#  ('19', 8),
#  ('music', 8),
#  ('speed', 8),
#  ('firm', 8),
#  ('perform', 8),
#  ('metrics', 8),
#  ('domain', 8),
#  ('worked', 8),
#  ('done', 8),
#  ('variety', 8),
#  ('designed', 8),
#  ('whatconverts', 8),
#  ('early', 8),
#  ('founders', 8),
#  ('virtual', 8),
#  ('incubation', 8),
#  ('rails', 8),
#  ('pipelines', 8),
#  ('zapiens', 8),
#  ('students', 8),
#  ('second', 8),
#  ('soltech', 8),
#  ('improvements', 7),
#  ('clearance', 7),
#  ('eligibility', 7),
#  ('channel', 7),
#  ('classroom', 7),
#  ('networks', 7),
#  ('typical', 7),
#  ('svn', 7),
#  ('dependent', 7),
#  ('architectures', 7),
#  ('levels', 7),
#  ('prescient', 7),
#  ('owned', 7),
#  ('government', 7),
#  ('citizen', 7),
#  ('conditions', 7),
#  ('moderate', 7),
#  ('applicant', 7),
#  ('communities', 7),
#  ('operational', 7),
#  ('commercial', 7),
#  ('visit', 7),
#  ('engage', 7),
#  ('several', 7),
#  ('notice', 7),
#  ('resource', 7),
#  ('inc', 7),
#  ('journey', 7),
#  ('expand', 7),
#  ('ask', 7),
#  ('excel', 7),
#  ('documenting', 7),
#  ('talent', 7),
#  ('requires', 7),
#  ('possess', 7),
#  ('lists', 7),
#  ('tool', 7),
#  ('workforce', 7),
#  ('easy', 7),
#  ('international', 7),
#  ('collaboratively', 7),
#  ('experts', 7),
#  ('order', 7),
#  ('types', 7),
#  ('alternative', 7),
#  ('procedures', 7),
#  ('supports', 7),
#  ('maintains', 7),
#  ('documented', 7),
#  ('necessary', 7),
#  ('container', 7),
#  ('contributor', 7),
#  ('highest', 7),
#  ('case', 7),
#  ('fire', 7),
#  ('communications', 7),
#  ('ways', 7),
#  ('builds', 7),
#  ('considered', 7),
#  ('ongoing', 7),
#  ('included', 7),
#  ('improving', 7),
#  ('internet', 7),
#  ('usd', 7),
#  ('decision', 7),
#  ('important', 7),
#  ('jr', 7),
#  ('consistently', 7),
#  ('demands', 7),
#  ('multi', 7),
#  ('covid', 7),
#  ('verification', 7),
#  ('even', 7),
#  ('nation', 7),
#  ('interpersonal', 7),
#  ('dev', 7),
#  ('optimizing', 7),
#  ('resources', 7),
#  ('proud', 7),
#  ('generation', 7),
#  ('stock', 7),
#  ('ranges', 7),
#  ('rewards', 7),
#  ('specifications', 7),
#  ('documentation', 7),
#  ('modeling', 7),
#  ('updates', 7),
#  ('translate', 7),
#  ('rust', 7),
#  ('bringing', 7),
#  ('founding', 7),
#  ('cofounder', 7),
#  ('autonomy', 7),
#  ('feature', 7),
#  ('superorder', 7),
#  ('footage', 7),
#  ('resolve', 6),
#  ('complete', 6),
#  ('approaches', 6),
#  ('considers', 6),
#  ('lifecycle', 6),
#  ('brmi', 6),
#  ('banking', 6),
#  ('vienna', 6),
#  ('va', 6),
#  ('pensacola', 6),
#  ('fl', 6),
#  ('bottlenecks', 6),
#  ('policies', 6),
#  ('condition', 6),
#  ('factor', 6),
#  ('id', 6),
#  ('category', 6),
#  ('title', 6),
#  ('none', 6),
#  ('tbd', 6),
#  ('thought', 6),
#  ('401k', 6),
#  ('accounts', 6),
#  ('sns', 6),
#  ('jira', 6),
#  ('permanent', 6),
#  ('resident', 6),
#  ('equipment', 6),
#  ('feel', 6),
#  ('reach', 6),
#  ('contact', 6),
#  ('accommodations', 6),
#  ('veterans', 6),
#  ('accordance', 6),
#  ('public', 6),
#  ('concentrix', 6),
#  ('applying', 6),
#  ('reliability', 6),
#  ('celebrate', 6),
#  ('click', 6),
#  ('pages', 6),
#  ('eager', 6),
#  ('expanding', 6),
#  ('collaborating', 6),
#  ...]

# %%
backend_top_skills = {'java': 67, 'aws': 63, 'apis': 60, 'python': 59, 'react': 48}

# %%
Counter(grouped_df.iloc[1]['description']).most_common()
# Out:
# [('data', 3919),
#  ('business', 1261),
#  ('experience', 1222),
#  ('work', 921),
#  ('analysis', 642),
#  ('skills', 631),
#  ('team', 616),
#  ('’', 508),
#  ('ability', 493),
#  ('support', 483),
#  ('analytics', 483),
#  ('knowledge', 470),
#  ('tools', 451),
#  ('quality', 423),
#  ('information', 406),
#  ('related', 401),
#  ('science', 385),
#  ('analyst', 377),
#  ('management', 365),
#  ('requirements', 356),
#  ('job', 353),
#  ('including', 345),
#  ('required', 344),
#  ('time', 343),
#  ('development', 338),
#  ('position', 324),
#  ('qualifications', 318),
#  ('company', 315),
#  ('sql', 315),
#  ('working', 314),
#  ('degree', 295),
#  ('using', 295),
#  ('new', 293),
#  ('reports', 293),
#  ('solutions', 292),
#  ('years', 280),
#  ('technical', 277),
#  ('strong', 276),
#  ('based', 274),
#  ('preferred', 259),
#  ('role', 258),
#  ('insights', 251),
#  ('benefits', 250),
#  ('systems', 247),
#  ('customer', 247),
#  ('provide', 245),
#  ('opportunity', 239),
#  ('environment', 238),
#  ('communication', 233),
#  ('analytical', 229),
#  ('statistics', 228),
#  ('research', 228),
#  ('understanding', 227),
#  ('health', 226),
#  ('field', 222),
#  ('python', 219),
#  ('status', 219),
#  ('responsibilities', 218),
#  ('models', 217),
#  ('develop', 217),
#  ('visualization', 215),
#  ('us', 214),
#  ('statistical', 214),
#  ('employment', 208),
#  ('practices', 207),
#  ('needs', 206),
#  ('identify', 206),
#  ('process', 206),
#  ('projects', 205),
#  ('processes', 205),
#  ('best', 204),
#  ('industry', 202),
#  ('reporting', 200),
#  ('level', 195),
#  ('computer', 195),
#  ('excel', 193),
#  ('opportunities', 192),
#  ('services', 191),
#  ('engineering', 190),
#  ('use', 190),
#  ('design', 188),
#  ('technology', 185),
#  ('techniques', 185),
#  ('help', 183),
#  ('employees', 180),
#  ('2', 178),
#  ('relevant', 178),
#  ('analyze', 178),
#  ('stakeholders', 177),
#  ('performance', 176),
#  ('within', 173),
#  ('apply', 173),
#  ('teams', 171),
#  ('people', 171),
#  ('program', 171),
#  ('clients', 170),
#  ('employer', 170),
#  ('make', 169),
#  ('multiple', 169),
#  ('equal', 168),
#  ('bachelor', 167),
#  ('across', 166),
#  ('tableau', 164),
#  ('disability', 163),
#  ('create', 161),
#  ('software', 160),
#  ('range', 156),
#  ('client', 154),
#  ('paid', 154),
#  ('product', 153),
#  ('project', 152),
#  ('complex', 152),
#  ('national', 151),
#  ('high', 150),
#  ('well', 150),
#  ('problem', 149),
#  ('learning', 149),
#  ('others', 149),
#  ('key', 149),
#  ('salary', 148),
#  ('trends', 146),
#  ('user', 145),
#  ('results', 145),
#  ('1', 144),
#  ('may', 142),
#  ('organization', 141),
#  ('build', 141),
#  ('full', 140),
#  ('location', 140),
#  ('learn', 140),
#  ('members', 139),
#  ('requires', 139),
#  ('plans', 139),
#  ('join', 138),
#  ('assist', 137),
#  ('one', 137),
#  ('diversity', 137),
#  ('e', 136),
#  ('r', 136),
#  ('must', 135),
#  ('education', 134),
#  ('intelligence', 134),
#  ('excellent', 133),
#  ('compensation', 133),
#  ('impact', 133),
#  ('remote', 132),
#  ('bi', 132),
#  ('office', 131),
#  ('understand', 131),
#  ('building', 131),
#  ('minimum', 131),
#  ('3', 131),
#  ('gender', 131),
#  ('perform', 130),
#  ('developing', 130),
#  ('issues', 128),
#  ('internal', 128),
#  ('advanced', 126),
#  ('professional', 126),
#  ('problems', 126),
#  ('financial', 126),
#  ('training', 125),
#  ('healthcare', 125),
#  ('part', 124),
#  ('life', 124),
#  ('000', 124),
#  ('modeling', 124),
#  ('ensure', 123),
#  ('enterprise', 123),
#  ('making', 122),
#  ('solving', 122),
#  ('applicants', 121),
#  ('please', 121),
#  ('operations', 121),
#  ('access', 121),
#  ('pay', 120),
#  ('supports', 120),
#  ('marketing', 120),
#  ('programs', 119),
#  ('improve', 118),
#  ('detail', 116),
#  ('maintain', 116),
#  ('languages', 116),
#  ('sources', 115),
#  ('power', 114),
#  ('customers', 114),
#  ('written', 113),
#  ('year', 113),
#  ('employee', 113),
#  ('providing', 112),
#  ('description', 112),
#  ('culture', 112),
#  ('mission', 111),
#  ('creating', 111),
#  ('recommendations', 111),
#  ('candidate', 110),
#  ('metrics', 110),
#  ('tasks', 109),
#  ('protected', 109),
#  ('growth', 109),
#  ('include', 109),
#  ('–', 108),
#  ('standards', 108),
#  ('driven', 107),
#  ('medical', 107),
#  ('leadership', 107),
#  ('sales', 107),
#  ('mathematics', 106),
#  ('race', 106),
#  ('orientation', 106),
#  ('appropriate', 106),
#  ('deliver', 106),
#  ('able', 105),
#  ('products', 105),
#  ('functional', 105),
#  ('responsible', 104),
#  ('insurance', 103),
#  ('large', 102),
#  ('career', 102),
#  ('religion', 102),
#  ('identity', 102),
#  ('service', 102),
#  ('documentation', 101),
#  ('origin', 101),
#  ('veteran', 101),
#  ('expertise', 101),
#  ('policies', 101),
#  ('procedures', 101),
#  ('existing', 100),
#  ('success', 100),
#  ('communicate', 100),
#  ('sexual', 100),
#  ('dashboards', 100),
#  ('plan', 100),
#  ('vision', 99),
#  ('database', 99),
#  ('applications', 99),
#  ('junior', 98),
#  ('areas', 98),
#  ('proficiency', 98),
#  ('drive', 98),
#  ('looking', 97),
#  ('etc', 97),
#  ('also', 97),
#  ('machine', 97),
#  ('implementation', 97),
#  ('ms', 97),
#  ('application', 97),
#  ('care', 97),
#  ('improvement', 97),
#  ('world', 96),
#  ('accuracy', 95),
#  ('effectively', 95),
#  ('datasets', 95),
#  ('finance', 95),
#  ('self', 94),
#  ('present', 94),
#  ('methods', 94),
#  ('color', 94),
#  ('commitment', 94),
#  ('g', 93),
#  ('duties', 93),
#  ('digital', 93),
#  ('focus', 92),
#  ('highly', 91),
#  ('various', 91),
#  ('guidance', 91),
#  ('values', 91),
#  ('activities', 91),
#  ('findings', 90),
#  ('diverse', 90),
#  ('entry', 89),
#  ('candidates', 88),
#  ('collaborate', 88),
#  ('attention', 88),
#  ('seeking', 88),
#  ('age', 88),
#  ('partners', 88),
#  ('policy', 88),
#  ('microsoft', 88),
#  ('integrity', 87),
#  ('databases', 87),
#  ('plus', 87),
#  ('action', 87),
#  ('without', 87),
#  ('economics', 87),
#  ('department', 86),
#  ('dental', 86),
#  ('decisions', 86),
#  ('qualified', 85),
#  ('future', 85),
#  ('meet', 85),
#  ('value', 85),
#  ('offer', 84),
#  ('programming', 84),
#  ('decision', 84),
#  ('sex', 84),
#  ('equivalent', 83),
#  ('change', 83),
#  ('non', 82),
#  ('needed', 81),
#  ('need', 81),
#  ('outcomes', 81),
#  ('testing', 81),
#  ('day', 81),
#  ('supporting', 81),
#  ('technologies', 80),
#  ('operational', 80),
#  ('supervision', 80),
#  ('public', 80),
#  ('scripting', 79),
#  ('states', 79),
#  ('committed', 79),
#  ('strategy', 79),
#  ('integration', 79),
#  ('market', 78),
#  ('additional', 78),
#  ('available', 78),
#  ('cross', 77),
#  ('flexible', 77),
#  ('functions', 77),
#  ('like', 76),
#  ('concepts', 76),
#  ('security', 76),
#  ('collection', 76),
#  ('analyzing', 75),
#  ('sets', 75),
#  ('package', 75),
#  ('first', 75),
#  ('conduct', 75),
#  ('state', 74),
#  ('communities', 74),
#  ('individual', 74),
#  ('global', 74),
#  ('example', 74),
#  ('competitive', 73),
#  ('com', 73),
#  ('system', 73),
#  ('demonstrated', 73),
#  ('provides', 73),
#  ('receive', 72),
#  ('necessary', 72),
#  ('united', 72),
#  ('innovation', 71),
#  ('law', 71),
#  ('primary', 70),
#  ('familiarity', 70),
#  ('following', 69),
#  ('organizational', 69),
#  ('compliance', 69),
#  ('cases', 69),
#  ('strategic', 69),
#  ('demonstrates', 69),
#  ('community', 68),
#  ('master', 68),
#  ('standard', 68),
#  ('visualizations', 68),
#  ('model', 68),
#  ('essential', 68),
#  ('review', 68),
#  ('relationships', 68),
#  ('variety', 67),
#  ('comprehensive', 67),
#  ('specific', 67),
#  ('federal', 67),
#  ('inclusive', 67),
#  ('scientist', 66),
#  ('government', 66),
#  ('clear', 65),
#  ('independently', 65),
#  ('assigned', 64),
#  ('challenges', 64),
#  ('individuals', 64),
#  ('manner', 64),
#  ('inclusion', 64),
#  ('platform', 64),
#  ('limited', 64),
#  ('verbal', 63),
#  ('u', 63),
#  ('manage', 62),
#  ('proficient', 62),
#  ('report', 62),
#  ('associates', 62),
#  ('source', 62),
#  ('focused', 62),
#  ('corporate', 62),
#  ('take', 62),
#  ('solve', 62),
#  ('end', 62),
#  ('regulatory', 62),
#  ('patterns', 61),
#  ('writing', 61),
#  ('critical', 61),
#  ('address', 61),
#  ('passion', 61),
#  ('serve', 61),
#  ('00', 60),
#  ('hiring', 60),
#  ('regard', 60),
#  ('bring', 60),
#  ('summary', 60),
#  ('analyses', 60),
#  ('social', 60),
#  ('changes', 59),
#  ('staff', 59),
#  ('different', 59),
#  ('ad', 59),
#  ('external', 59),
#  ('actionable', 58),
#  ('types', 58),
#  ('5', 58),
#  ('better', 58),
#  ('evaluation', 58),
#  ('delivery', 58),
#  ('leading', 58),
#  ('initiatives', 58),
#  ('quantitative', 58),
#  ('storage', 58),
#  ('schedule', 57),
#  ('top', 57),
#  ('basic', 57),
#  ('set', 57),
#  ('closely', 57),
#  ('identification', 57),
#  ('basis', 57),
#  ('execute', 57),
#  ('base', 57),
#  ('factors', 57),
#  ('collaboration', 57),
#  ('type', 56),
#  ('companies', 56),
#  ('implement', 55),
#  ('language', 55),
#  ('discipline', 55),
#  ('member', 55),
#  ('oriented', 54),
#  ('mining', 54),
#  ('desired', 54),
#  ('successful', 54),
#  ('big', 54),
#  ('requests', 54),
#  ('great', 54),
#  ('fast', 53),
#  ('hours', 53),
#  ('innovative', 53),
#  ('around', 53),
#  ('ways', 53),
#  ('thinking', 53),
#  ('hoc', 53),
#  ('guidelines', 53),
#  ('listed', 53),
#  ('cleansing', 53),
#  ('per', 52),
#  ('oracle', 52),
#  ('date', 52),
#  ('leave', 52),
#  ('current', 52),
#  ('effective', 52),
#  ('performing', 52),
#  ('personal', 52),
#  ('accounting', 52),
#  ('identifying', 52),
#  ('resources', 52),
#  ('term', 52),
#  ('open', 51),
#  ('similar', 51),
#  ('assistance', 51),
#  ('home', 51),
#  ('details', 51),
#  ('predictive', 51),
#  ('works', 51),
#  ('includes', 51),
#  ('mindset', 51),
#  ('test', 51),
#  ('equity', 51),
#  ('automation', 51),
#  ('group', 50),
#  ('planning', 50),
#  ('real', 50),
#  ('goals', 50),
#  ('local', 50),
#  ('ideas', 50),
#  ('offers', 50),
#  ('believe', 50),
#  ('accommodation', 50),
#  ('direction', 50),
#  ('expert', 50),
#  ('google', 49),
#  ('roles', 49),
#  ('analytic', 49),
#  ('directly', 49),
#  ('grow', 49),
#  ('growing', 49),
#  ('applicable', 49),
#  ('options', 49),
#  ('none', 49),
#  ('person', 48),
#  ('bonus', 48),
#  ('4', 48),
#  ('consideration', 48),
#  ('forward', 48),
#  ('collaboratively', 48),
#  ('abilities', 48),
#  ('every', 48),
#  ('achieve', 48),
#  ('methodologies', 48),
#  ('engineers', 48),
#  ('america', 48),
#  ('demonstrate', 48),
#  ('kdd', 48),
#  ('improvements', 47),
#  ('users', 47),
#  ('processing', 47),
#  ('physical', 47),
#  ('objectives', 47),
#  ('powerbi', 47),
#  ('option', 47),
#  ('provided', 46),
#  ('exceptional', 46),
#  ('supply', 46),
#  ('partner', 46),
#  ('right', 46),
#  ('eligible', 46),
#  ('governance', 46),
#  ('influence', 46),
#  ('walmart', 45),
#  ('assess', 45),
#  ('considered', 45),
#  ('human', 45),
#  ('manager', 45),
#  ('background', 45),
#  ('outlined', 45),
#  ('generate', 45),
#  ('code', 45),
#  ('evaluate', 45),
#  ('·', 45),
#  ('core', 44),
#  ('collect', 44),
#  ('contact', 44),
#  ('risk', 44),
#  ('structures', 44),
#  ('match', 44),
#  ('senior', 44),
#  ('consulting', 44),
#  ('engagement', 44),
#  ('discovery', 44),
#  ('questions', 44),
#  ('general', 44),
#  ('goal', 44),
#  ('perspectives', 44),
#  ('potential', 43),
#  ('leaders', 43),
#  ('utilize', 43),
#  ('100', 43),
#  ('organizations', 43),
#  ('story', 43),
#  ('reasonable', 43),
#  ('algorithms', 43),
#  ('environmental', 43),
#  ('maintains', 43),
#  ('curiosity', 43),
#  ('401', 42),
#  ('k', 42),
#  ('proven', 42),
#  ('exploratory', 42),
#  ('privacy', 42),
#  ('execution', 42),
#  ('simple', 42),
#  ('depth', 42),
#  ('family', 42),
#  ('two', 42),
#  ('presentations', 41),
#  ('cleaning', 41),
#  ('holidays', 41),
#  ('obtain', 41),
#  ('server', 41),
#  ('require', 41),
#  ('“', 41),
#  ('genetic', 41),
#  ('audiences', 41),
#  ('platforms', 41),
#  ('leverage', 41),
#  ('paced', 40),
#  ('tech', 40),
#  ('want', 40),
#  ('responsibility', 40),
#  ('cost', 40),
#  ('live', 40),
#  ('managing', 40),
#  ('know', 40),
#  ('affirmative', 40),
#  ('”', 40),
#  ('arsenault', 40),
#  ('positive', 40),
#  ('marital', 40),
#  ('monitor', 40),
#  ('transformation', 40),
#  ('web', 40),
#  ('framework', 40),
#  ('long', 40),
#  ('approach', 40),
#  ('suitable', 40),
#  ('completion', 39),
#  ('interpersonal', 39),
#  ('lead', 39),
#  ('clearance', 39),
#  ('days', 39),
#  ('queries', 39),
#  ('oral', 39),
#  ('today', 39),
#  ('hybrid', 39),
#  ('assisting', 39),
#  ('interpret', 39),
#  ('unique', 39),
#  ('online', 39),
#  ('warehousing', 39),
#  ('wide', 38),
#  ('jobs', 38),
#  ('meaningful', 38),
#  ('maintaining', 38),
#  ('contract', 38),
#  ('many', 38),
#  ('track', 38),
#  ('prepare', 38),
#  ('guide', 38),
#  ('enable', 38),
#  ('annual', 38),
#  ('capabilities', 38),
#  ('claims', 38),
#  ('context', 38),
#  ('possible', 37),
#  ('ensuring', 37),
#  ('skill', 37),
#  ('validate', 37),
#  ('parental', 37),
#  ('interest', 37),
#  ('area', 37),
#  ('prior', 37),
#  ('contribute', 37),
#  ('analysts', 37),
#  ('salesforce', 37),
#  ('everyone', 37),
#  ('would', 37),
#  ('updates', 37),
#  ('stakeholder', 37),
#  ('embraces', 37),
#  ('content', 37),
#  ('solution', 37),
#  ('ethics', 37),
#  ('efficiency', 36),
#  ('applying', 36),
#  ('sas', 36),
#  ('control', 36),
#  ('chain', 36),
#  ('administration', 36),
#  ('talent', 36),
#  ('continuous', 36),
#  ('strategies', 36),
#  ('applied', 36),
#  ('domain', 36),
#  ('efforts', 36),
#  ('apache', 36),
#  ('possess', 35),
#  ('currently', 35),
#  ('site', 35),
#  ('participate', 35),
#  ('word', 35),
#  ('descriptive', 35),
#  ('higher', 35),
#  ('locations', 35),
#  ('least', 35),
#  ('city', 35),
#  ('progress', 35),
#  ('emerging', 35),
#  ('scientists', 35),
#  ('ai', 35),
#  ('technique', 35),
#  ('multi', 34),
#  ('good', 34),
#  ('website', 34),
#  ('become', 34),
#  ('suite', 34),
#  ('dashboard', 34),
#  ('presentation', 34),
#  ('mapping', 34),
#  ('document', 34),
#  ('highest', 34),
#  ('center', 34),
#  ('agile', 34),
#  ('search', 34),
#  ('translate', 34),
#  ('warehouse', 34),
#  ('awareness', 34),
#  ('together', 34),
#  ('recruiting', 34),
#  ('account', 34),
#  ('monitoring', 34),
#  ('measures', 34),
#  ('benefit', 33),
#  ('motivated', 33),
#  ('determine', 33),
#  ('extract', 33),
#  ('encourage', 33),
#  ('packages', 33),
#  ('daily', 33),
#  ('school', 33),
#  ('monthly', 33),
#  ('ideal', 33),
#  ('consider', 33),
#  ('workplace', 33),
#  ('demands', 33),
#  ('internship', 33),
#  ('dedicated', 33),
#  ('enhance', 33),
#  ('deadlines', 33),
#  ('network', 33),
#  ('gather', 33),
#  ('disabilities', 33),
#  ('subject', 33),
#  ('travel', 33),
#  ('scale', 33),
#  ('definitions', 33),
#  ('architecture', 33),
#  ('n', 33),
#  ('total', 32),
#  ('conducting', 32),
#  ('throughout', 32),
#  ('certification', 32),
#  ('regulations', 32),
#  ('upon', 32),
#  ('energy', 32),
#  ('transform', 32),
#  ('patient', 32),
#  ('trust', 32),
#  ('made', 32),
#  ('accurate', 32),
#  ('email', 32),
#  ('military', 32),
#  ('validation', 32),
#  ('retail', 32),
#  ('mahout', 32),
#  ('gain', 31),
#  ('creation', 31),
#  ('sponsorship', 31),
#  ('several', 31),
#  ('reviews', 31),
#  ('401k', 31),
#  ('expression', 31),
#  ('pregnancy', 31),
#  ('helping', 31),
#  ('organize', 31),
#  ('conditions', 31),
#  ('timely', 31),
#  ('prioritize', 31),
#  ('line', 31),
#  ('foster', 31),
#  ('agency', 31),
#  ('retirement', 31),
#  ('spark', 31),
#  ('embrace', 31),
#  ('format', 31),
#  ('maintenance', 31),
#  ('assessments', 31),
#  ('delivering', 31),
#  ('metadata', 31),
#  ('start', 30),
#  ('previous', 30),
#  ('clean', 30),
#  ('international', 30),
#  ('place', 30),
#  ('implementing', 30),
#  ('interested', 30),
#  ('discriminate', 30),
#  ('records', 30),
#  ('coverage', 30),
#  ('develops', 30),
#  ('used', 30),
#  ('improving', 30),
#  ('b', 30),
#  ('frameworks', 30),
#  ('levels', 29),
#  ('task', 29),
#  ('get', 29),
#  ('positions', 29),
#  ('cloud', 29),
#  ('inc', 29),
#  ('love', 29),
#  ('regarding', 29),
#  ('principles', 29),
#  ('6', 29),
#  ('optimize', 29),
#  ('addition', 29),
#  ('coding', 29),
#  ('citizenship', 29),
#  ('overview', 29),
#  ('designed', 29),
#  ('specialist', 29),
#  ('vacation', 29),
#  ('ongoing', 29),
#  ('drivers', 29),
#  ('dynamic', 29),
#  ('hr', 29),
#  ('successfully', 29),
#  ('agencies', 29),
#  ('broad', 29),
#  ('check', 28),
#  ('portfolio', 28),
#  ('exposure', 28),
#  ('enjoy', 28),
#  ('10', 28),
#  ('efficient', 28),
#  ('student', 28),
#  ('expected', 28),
#  ('www', 28),
#  ('savings', 28),
#  ('stock', 28),
#  ('overall', 28),
#  ('allowing', 28),
#  ('profiling', 28),
#  ('front', 28),
#  ('production', 28),
#  ('find', 28),
#  ('matter', 28),
#  ('passionate', 28),
#  ('explain', 28),
#  ('promote', 28),
#  ('actively', 28),
#  ('grant', 28),
#  ('heartland', 28),
#  ('hands', 27),
#  ('common', 27),
#  ('gathering', 27),
#  ('flexibility', 27),
#  ('record', 27),
#  ('contributions', 27),
#  ('desire', 27),
#  ('incentive', 27),
#  ('class', 27),
#  ('accountable', 27),
#  ('collaborative', 27),
#  ('pre', 27),
#  ('optional', 27),
#  ('hire', 27),
#  ('target', 27),
#  ('setting', 27),
#  ('college', 27),
#  ('explore', 27),
#  ('look', 27),
#  ('e2e', 27),
#  ('resume', 26),
#  ('see', 26),
#  ('meetings', 26),
#  ('inventory', 26),
#  ('collecting', 26),
#  ('sick', 26),
#  ('query', 26),
#  ('statement', 26),
#  ('define', 26),
#  ('priorities', 26),
#  ('next', 26),
#  ('firm', 26),
#  ('executing', 26),
#  ('workforce', 26),
#  ('taking', 26),
#  ('go', 26),
#  ('keep', 26),
#  ('generous', 26),
#  ('profile', 26),
#  ('order', 26),
#  ('veterans', 26),
#  ('pipelines', 26),
#  ('events', 25),
#  ('visit', 25),
#  ('inform', 25),
#  ('act', 25),
#  ('detailed', 25),
#  ('input', 25),
#  ('powerpoint', 25),
#  ('backgrounds', 25),
#  ('mental', 25),
#  ('associate', 25),
#  ('assurance', 25),
#  ('extensive', 25),
#  ('determining', 25),
#  ('wellness', 25),
#  ('perspective', 25),
#  ('three', 25),
#  ('designing', 25),
#  ('optimization', 25),
#  ('follow', 25),
#  ('nosql', 25),
#  ('accommodations', 25),
#  ('managers', 25),
#  ('significant', 25),
#  ('certifications', 25),
#  ('interface', 25),
#  ('distributed', 25),
#  ('justice', 25),
#  ('audience', 25),
#  ('guidehouse', 25),
#  ('accenture', 25),
#  ('forms', 24),
#  ('stay', 24),
#  ('manipulation', 24),
#  ('purpose', 24),
#  ('actions', 24),
#  ('weekly', 24),
#  ('resilience', 24),
#  ('lives', 24),
#  ('bs', 24),
#  ('accordance', 24),
#  ('changing', 24),
#  ('submit', 24),
#  ('valuable', 24),
#  ('ssc', 24),
#  ('initial', 24),
#  ('builds', 24),
#  ('consumer', 24),
#  ('implications', 24),
#  ('collaborating', 24),
#  ('communications', 24),
#  ('azure', 24),
#  ('journey', 24),
#  ('sustainability', 24),
#  ('mentor', 24),
#  ('applicant', 24),
#  ('ecommerce', 24),
#  ('sports', 23),
#  ('hour', 23),
#  ('click', 23),
#  ('correlations', 23),
#  ('demonstrating', 23),
#  ('play', 23),
#  ('8', 23),
#  ('important', 23),
#  ('excellence', 23),
#  ('handle', 23),
#  ('facilitate', 23),
#  ('geospatial', 23),
#  ('complete', 23),
#  ('partnerships', 23),
#  ('comfortable', 23),
#  ('deep', 23),
#  ('deliverables', 23),
#  ('clinical', 23),
#  ('professionals', 23),
#  ('washington', 23),
#  ('custom', 23),
#  ('infrastructure', 23),
#  ('retention', 23),
#  ('months', 23),
#  ('safety', 23),
#  ('indicators', 23),
#  ('libraries', 23),
#  ('domains', 23),
#  ('scala', 23),
#  ('bentonville', 23),
#  ('automated', 23),
#  ('located', 22),
#  ('https', 22),
#  ('competing', 22),
#  ('event', 22),
#  ('way', 22),
#  ('party', 22),
#  ('surveys', 22),
#  ('experienced', 22),
#  ('could', 22),
#  ('demand', 22),
#  ('regular', 22),
#  ('tables', 22),
#  ('characteristic', 22),
#  ('combination', 22),
#  ('students', 22),
#  ('advance', 22),
#  ('shared', 22),
#  ('25', 22),
#  ('scenarios', 22),
#  ('vary', 22),
#  ('emotional', 22),
#  ('thrive', 22),
#  ('country', 22),
#  ('outliers', 22),
#  ('points', 22),
#  ('accounts', 22),
#  ('audit', 22),
#  ('experts', 22),
#  ('etl', 22),
#  ('interview', 22),
#  ('utility', 22),
#  ('reimbursement', 22),
#  ('implements', 22),
#  ('advice', 22),
#  ('consistently', 22),
#  ('intelligent', 22),
#  ('merchandising', 22),
#  ('ar', 22),
#  ('exciting', 21),
#  ('provider', 21),
#  ('cause', 21),
#  ('balance', 21),
#  ...]

# %%
data_analyst_top_skills = {'sql': 315, 'python': 219, 'excel': 193, 'tableau': 164, 'power': 114}

# %%
Counter(grouped_df.iloc[2]['description']).most_common()
# Out:
# [('data', 1926),
#  ('experience', 706),
#  ('work', 438),
#  ('science', 392),
#  ('analysis', 356),
#  ('business', 324),
#  ('skills', 305),
#  ('analytics', 278),
#  ('team', 254),
#  ('ability', 230),
#  ('job', 216),
#  ('position', 215),
#  ('support', 213),
#  ('learning', 209),
#  ('development', 208),
#  ('information', 204),
#  ('including', 204),
#  ('scientist', 195),
#  ('’', 194),
#  ('tools', 192),
#  ('time', 185),
#  ('required', 185),
#  ('solutions', 181),
#  ('degree', 180),
#  ('technical', 167),
#  ('benefits', 161),
#  ('opportunity', 160),
#  ('develop', 160),
#  ('techniques', 154),
#  ('research', 154),
#  ('knowledge', 153),
#  ('working', 151),
#  ('years', 150),
#  ('models', 150),
#  ('related', 149),
#  ('requirements', 149),
#  ('statistical', 146),
#  ('using', 146),
#  ('employment', 145),
#  ('provide', 145),
#  ('machine', 144),
#  ('strong', 142),
#  ('python', 141),
#  ('apply', 138),
#  ('status', 137),
#  ('new', 135),
#  ('may', 134),
#  ('complex', 132),
#  ('engineering', 132),
#  ('us', 132),
#  ('must', 132),
#  ('environment', 130),
#  ('qualifications', 129),
#  ('computer', 122),
#  ('sql', 121),
#  ('company', 119),
#  ('software', 118),
#  ('opportunities', 118),
#  ('world', 117),
#  ('projects', 116),
#  ('employees', 116),
#  ('health', 115),
#  ('role', 114),
#  ('level', 114),
#  ('responsibilities', 112),
#  ('based', 111),
#  ('statistics', 111),
#  ('full', 110),
#  ('insights', 109),
#  ('product', 109),
#  ('management', 108),
#  ('advanced', 107),
#  ('identify', 106),
#  ('field', 105),
#  ('within', 103),
#  ('modeling', 100),
#  ('e', 99),
#  ('disability', 99),
#  ('quality', 98),
#  ('problems', 98),
#  ('national', 98),
#  ('teams', 98),
#  ('analytical', 97),
#  ('life', 96),
#  ('visualization', 96),
#  ('program', 96),
#  ('please', 95),
#  ('processes', 95),
#  ('applicants', 95),
#  ('gender', 94),
#  ('r', 93),
#  ('education', 92),
#  ('relevant', 90),
#  ('process', 90),
#  ('security', 90),
#  ('range', 89),
#  ('methods', 88),
#  ('systems', 88),
#  ('n', 88),
#  ('equal', 87),
#  ('performance', 87),
#  ('use', 86),
#  ('industry', 85),
#  ('employer', 85),
#  ('bachelor', 85),
#  ('ensure', 84),
#  ('reports', 84),
#  ('year', 84),
#  ('developing', 84),
#  ('across', 84),
#  ('analyst', 83),
#  ('1', 82),
#  ('key', 82),
#  ('design', 82),
#  ('communication', 82),
#  ('preferred', 82),
#  ('compensation', 82),
#  ('career', 81),
#  ('problem', 81),
#  ('help', 80),
#  ('make', 80),
#  ('application', 80),
#  ('training', 79),
#  ('programming', 77),
#  ('predictive', 77),
#  ('clients', 76),
#  ('project', 76),
#  ('well', 76),
#  ('g', 75),
#  ('technology', 75),
#  ('services', 74),
#  ('description', 72),
#  ('veteran', 72),
#  ('location', 72),
#  ('identity', 72),
#  ('one', 72),
#  ('professional', 71),
#  ('join', 71),
#  ('needs', 71),
#  ('sources', 71),
#  ('candidate', 71),
#  ('insurance', 70),
#  ('programs', 70),
#  ('clearance', 70),
#  ('collaborate', 70),
#  ('algorithms', 70),
#  ('intelligence', 70),
#  ('include', 70),
#  ('pay', 70),
#  ('orientation', 69),
#  ('stakeholders', 69),
#  ('2', 69),
#  ('solving', 69),
#  ('mathematics', 68),
#  ('protected', 68),
#  ('operations', 68),
#  ('customers', 68),
#  ('client', 67),
#  ('excellent', 67),
#  ('high', 67),
#  ('etc', 66),
#  ('driven', 66),
#  ('part', 66),
#  ('qualified', 66),
#  ('expertise', 66),
#  ('system', 66),
#  ('best', 65),
#  ('build', 65),
#  ('internal', 65),
#  ('salary', 65),
#  ('customer', 65),
#  ('vision', 64),
#  ('improve', 64),
#  ('religion', 64),
#  ('datasets', 64),
#  ('analyze', 64),
#  ('also', 64),
#  ('university', 64),
#  ('000', 64),
#  ('penn', 64),
#  ('drive', 63),
#  ('sexual', 63),
#  ('perform', 63),
#  ('analytic', 63),
#  ('organization', 63),
#  ('decision', 62),
#  ('u', 62),
#  ('trends', 62),
#  ('model', 62),
#  ('responsible', 62),
#  ('effectively', 62),
#  ('race', 61),
#  ('creating', 61),
#  ('written', 60),
#  ('offer', 60),
#  ('master', 60),
#  ('large', 60),
#  ('various', 60),
#  ('serco', 60),
#  ('candidates', 59),
#  ('color', 59),
#  ('communicate', 59),
#  ('people', 59),
#  ('understanding', 59),
#  ('state', 59),
#  ('offers', 59),
#  ('medical', 58),
#  ('3', 57),
#  ('employee', 57),
#  ('technologies', 57),
#  ('mission', 57),
#  ('understand', 56),
#  ('results', 56),
#  ('origin', 56),
#  ('age', 56),
#  ('duties', 56),
#  ('plus', 56),
#  ('cloud', 56),
#  ('impact', 56),
#  ('quantitative', 56),
#  ('following', 55),
#  ('without', 55),
#  ('com', 55),
#  ('junior', 54),
#  ('decisions', 54),
#  ('reporting', 54),
#  ('multiple', 54),
#  ('paid', 53),
#  ('remote', 53),
#  ('global', 53),
#  ('service', 53),
#  ('individuals', 53),
#  ('law', 53),
#  ('considered', 53),
#  ('language', 52),
#  ('success', 52),
#  ('personal', 52),
#  ('governance', 52),
#  ('accuracy', 51),
#  ('processing', 51),
#  ('deliver', 51),
#  ('products', 51),
#  ('learn', 51),
#  ('receive', 51),
#  ('analyses', 51),
#  ('care', 51),
#  ('supporting', 50),
#  ('scientists', 50),
#  ('every', 50),
#  ('day', 50),
#  ('implement', 50),
#  ('assistance', 50),
#  ('diverse', 50),
#  ('community', 50),
#  ('sets', 50),
#  ('challenges', 50),
#  ('solve', 49),
#  ('tableau', 49),
#  ('maintain', 49),
#  ('eligible', 49),
#  ('like', 48),
#  ('create', 48),
#  ('sex', 48),
#  ('recommendations', 48),
#  ('building', 48),
#  ('able', 48),
#  ('digital', 48),
#  ('ai', 48),
#  ('appropriate', 47),
#  ('power', 47),
#  ('plan', 47),
#  ('functional', 47),
#  ('applications', 47),
#  ('making', 47),
#  ('variety', 47),
#  ('flexible', 47),
#  ('federal', 47),
#  ('procedures', 46),
#  ('committed', 46),
#  ('bi', 46),
#  ('issues', 46),
#  ('competitive', 46),
#  ('accommodation', 46),
#  ('equivalent', 45),
#  ('future', 45),
#  ('includes', 45),
#  ('00', 45),
#  ('staff', 45),
#  ('entry', 44),
#  ('practices', 44),
#  ('standards', 44),
#  ('basic', 44),
#  ('members', 44),
#  ('minimum', 44),
#  ('applicable', 43),
#  ('comprehensive', 43),
#  ('action', 43),
#  ('seeking', 43),
#  ('engineers', 43),
#  ('needed', 43),
#  ('activities', 43),
#  ('obtain', 43),
#  ('familiarity', 43),
#  ('non', 42),
#  ('travel', 42),
#  ('critical', 42),
#  ('basis', 42),
#  ('government', 42),
#  ('meet', 42),
#  ('dental', 41),
#  ('analyzing', 41),
#  ('culture', 41),
#  ('cross', 41),
#  ('conduct', 41),
#  ('implementation', 41),
#  ('highly', 41),
#  ('proficiency', 41),
#  ('guidehouse', 41),
#  ('real', 40),
#  ('leading', 40),
#  ('take', 40),
#  ('manage', 40),
#  ('regard', 40),
#  ('wide', 40),
#  ('value', 40),
#  ('looking', 39),
#  ('specific', 39),
#  ('consideration', 39),
#  ('test', 39),
#  ('dashboards', 39),
#  ('additional', 38),
#  ('diversity', 38),
#  ('excel', 38),
#  ('languages', 38),
#  ('pipelines', 38),
#  ('provides', 38),
#  ('need', 38),
#  ('access', 38),
#  ('growth', 38),
#  ('email', 38),
#  ('current', 38),
#  ('database', 38),
#  ('strategy', 38),
#  ('require', 37),
#  ('deep', 37),
#  ('optimization', 37),
#  ('collection', 37),
#  ('production', 37),
#  ('manner', 37),
#  ('fast', 37),
#  ('functions', 37),
#  ('resources', 37),
#  ('mining', 37),
#  ('providing', 37),
#  ('market', 36),
#  ('site', 36),
#  ('change', 36),
#  ('innovation', 36),
#  ('background', 36),
#  ('detail', 36),
#  ('effective', 36),
#  ('family', 36),
#  ('self', 36),
#  ('external', 36),
#  ('questions', 36),
#  ('areas', 35),
#  ('tasks', 35),
#  ('office', 35),
#  ('package', 35),
#  ('attention', 35),
#  ('verbal', 35),
#  ('used', 35),
#  ('approaches', 35),
#  ('present', 34),
#  ('lead', 34),
#  ('findings', 34),
#  ('demonstrated', 34),
#  ('collaboration', 34),
#  ('reasonable', 34),
#  ('annual', 34),
#  ('public', 34),
#  ('5', 34),
#  ('innovative', 34),
#  ('assist', 33),
#  ('summary', 33),
#  ('edge', 33),
#  ('leadership', 33),
#  ('ad', 33),
#  ('writing', 33),
#  ('successful', 33),
#  ('capabilities', 33),
#  ('computational', 33),
#  ('secret', 33),
#  ('tuition', 33),
#  ('retirement', 33),
#  ('existing', 33),
#  ('applying', 32),
#  ('affirmative', 32),
#  ('utilize', 32),
#  ('concepts', 32),
#  ('least', 32),
#  ('desired', 32),
#  ('locations', 32),
#  ('college', 32),
#  ('aws', 32),
#  ('ml', 32),
#  ('testing', 31),
#  ('states', 31),
#  ('exploratory', 31),
#  ('big', 31),
#  ('network', 31),
#  ('group', 31),
#  ('defense', 31),
#  ('date', 31),
#  ('strategies', 31),
#  ('expression', 31),
#  ('enable', 31),
#  ('citizenship', 31),
#  ('plans', 31),
#  ('implementing', 31),
#  ('military', 31),
#  ('strategic', 31),
#  ('top', 30),
#  ('individual', 30),
#  ('visit', 30),
#  ('limited', 30),
#  ('different', 30),
#  ('applied', 30),
#  ('grow', 30),
#  ('senior', 30),
#  ('organizational', 30),
#  ('abt', 30),
#  ('hands', 29),
#  ('frameworks', 29),
#  ('visualizations', 29),
#  ('100', 29),
#  ('microsoft', 29),
#  ('paced', 29),
#  ('term', 29),
#  ('hours', 29),
#  ('local', 29),
#  ('databases', 29),
#  ('title', 28),
#  ('today', 28),
#  ('optimize', 28),
#  ('policies', 28),
#  ('efficiency', 28),
#  ('hoc', 28),
#  ('focus', 28),
#  ('end', 28),
#  ('exceptional', 28),
#  ('via', 28),
#  ('compliance', 28),
#  ('order', 28),
#  ('experts', 28),
#  ('nsa', 28),
#  ('review', 27),
#  ('united', 27),
#  ('ts', 27),
#  ('sci', 27),
#  ('environments', 27),
#  ('commitment', 27),
#  ('integrity', 27),
#  ('per', 27),
#  ('encourage', 27),
#  ('physical', 27),
#  ('platforms', 27),
#  ('closely', 27),
#  ('thinking', 27),
#  ('person', 27),
#  ('c', 27),
#  ('partners', 27),
#  ('documentation', 27),
#  ('factors', 27),
#  ('methodologies', 27),
#  ('better', 27),
#  ('total', 27),
#  ('cgi', 27),
#  ('user', 26),
#  ('patterns', 26),
#  ('b', 26),
#  ('levels', 26),
#  ('enterprise', 26),
#  ('good', 26),
#  ('automation', 26),
#  ('essential', 26),
#  ('discipline', 26),
#  ('schedule', 26),
#  ('days', 26),
#  ('leave', 26),
#  ('code', 26),
#  ('marketing', 26),
#  ('core', 25),
#  ('necessary', 25),
#  ('selection', 25),
#  ('around', 25),
#  ('focused', 25),
#  ('similar', 25),
#  ('structured', 25),
#  ('overview', 25),
#  ('policy', 25),
#  ('collect', 25),
#  ('cleaning', 25),
#  ('department', 25),
#  ('growing', 25),
#  ('clear', 25),
#  ('motivated', 25),
#  ('designing', 25),
#  ('marital', 25),
#  ('bring', 25),
#  ('agencies', 25),
#  ('get', 25),
#  ('home', 25),
#  ('social', 25),
#  ('bonus', 25),
#  ('genetic', 25),
#  ('incumbent', 25),
#  ('scientific', 24),
#  ('sas', 24),
#  ('complete', 24),
#  ('type', 24),
#  ('computing', 24),
#  ('evaluate', 24),
#  ('would', 24),
#  ('independently', 24),
#  ('initiatives', 24),
#  ('evaluation', 24),
#  ('platform', 24),
#  ('contact', 24),
#  ('set', 24),
#  ('participate', 24),
#  ('school', 24),
#  ('collaborative', 24),
#  ('preference', 24),
#  ('meaningful', 24),
#  ('outcomes', 24),
#  ('resumes', 24),
#  ('ibm', 24),
#  ('responsibility', 23),
#  ('area', 23),
#  ('general', 23),
#  ('scripting', 23),
#  ('dod', 23),
#  ('place', 23),
#  ('www', 23),
#  ('queries', 23),
#  ('dedicated', 23),
#  ('early', 23),
#  ('contribute', 23),
#  ('metrics', 23),
#  ('great', 23),
#  ('passionate', 23),
#  ('files', 23),
#  ('special', 23),
#  ('depth', 23),
#  ('works', 23),
#  ('agile', 23),
#  ('etl', 23),
#  ('contract', 23),
#  ('assigned', 23),
#  ('accurate', 23),
#  ('k', 22),
#  ('holidays', 22),
#  ('skill', 22),
#  ('open', 22),
#  ('networks', 22),
#  ('simulation', 22),
#  ('many', 22),
#  ('clean', 22),
#  ('sciences', 22),
#  ('maintaining', 22),
#  ('financial', 22),
#  ('artificial', 22),
#  ('unique', 22),
#  ('healthcare', 22),
#  ('condition', 22),
#  ('heart', 22),
#  ('address', 22),
#  ('extract', 22),
#  ('faculty', 22),
#  ('class', 22),
#  ('dependent', 22),
#  ('subject', 22),
#  ('identifying', 22),
#  ('unsolicited', 22),
#  ('addition', 22),
#  ('corporate', 21),
#  ('available', 21),
#  ('java', 21),
#  ('primary', 21),
#  ('active', 21),
#  ('natural', 21),
#  ('inclusive', 21),
#  ('leaders', 21),
#  ('enhance', 21),
#  ('hybrid', 21),
#  ('right', 21),
#  ('integrated', 21),
#  ('monitor', 21),
#  ('believe', 21),
#  ('careers', 21),
#  ('partner', 21),
#  ('standard', 21),
#  ('consistent', 21),
#  ('delivery', 21),
#  ('–', 21),
#  ('manufacturing', 21),
#  ('define', 21),
#  ('higher', 20),
#  ('coverage', 20),
#  ('scope', 20),
#  ('certification', 20),
#  ('interpret', 20),
#  ('prepare', 20),
#  ('communities', 20),
#  ('generation', 20),
#  ('guidance', 20),
#  ('balance', 20),
#  ('throughout', 20),
#  ('veterans', 20),
#  ('experienced', 20),
#  ('oriented', 20),
#  ('disabilities', 20),
#  ('10', 20),
#  ('pdri', 20),
#  ('devlab', 20),
#  ('economics', 20),
#  ('resume', 20),
#  ('creed', 20),
#  ('long', 20),
#  ('transformation', 20),
#  ('ideal', 20),
#  ('401k', 20),
#  ('planning', 20),
#  ('match', 19),
#  ('recent', 19),
#  ('positions', 19),
#  ('forecasting', 19),
#  ('detection', 19),
#  ('goals', 19),
#  ('possible', 19),
#  ('human', 19),
#  ('conducting', 19),
#  ('major', 19),
#  ('made', 19),
#  ('agency', 19),
#  ('check', 19),
#  ('way', 19),
#  ('number', 19),
#  ('start', 19),
#  ('first', 19),
#  ('interested', 19),
#  ('dynamic', 19),
#  ('assessments', 19),
#  ('collaboratively', 19),
#  ('member', 19),
#  ('others', 19),
#  ('note', 19),
#  ('statement', 19),
#  ('presentation', 19),
#  ('improvements', 19),
#  ('two', 19),
#  ('managing', 19),
#  ('solution', 19),
#  ('demonstrate', 19),
#  ('roles', 19),
#  ('ii', 19),
#  ('texas', 19),
#  ('yield', 19),
#  ('hiring', 18),
#  ('linear', 18),
#  ('spark', 18),
#  ('math', 18),
#  ('feature', 18),
#  ('thrive', 18),
#  ('timely', 18),
#  ('improvement', 18),
#  ('search', 18),
#  ('regression', 18),
#  ('azure', 18),
#  ('currently', 18),
#  ('packages', 18),
#  ('find', 18),
#  ('approach', 18),
#  ('educational', 18),
#  ('robust', 18),
#  ('mathematical', 18),
#  ('4', 18),
#  ('investigation', 18),
#  ('documents', 18),
#  ('equity', 18),
#  ('proficient', 18),
#  ('ideas', 18),
#  ('actionable', 18),
#  ('applicant', 18),
#  ('integration', 18),
#  ('chance', 18),
#  ('objectives', 18),
#  ('conditions', 18),
#  ('mental', 18),
#  ('coding', 17),
#  ('401', 17),
#  ('google', 17),
#  ('stay', 17),
#  ('md', 17),
#  ('direct', 17),
#  ('combination', 17),
#  ('prior', 17),
#  ('operational', 17),
#  ('inclusion', 17),
#  ('values', 17),
#  ('legally', 17),
#  ('infrastructure', 17),
#  ('cutting', 17),
#  ('criminal', 17),
#  ('record', 17),
#  ('academic', 17),
#  ('student', 17),
#  ('tensorflow', 17),
#  ('potential', 17),
#  ('talented', 17),
#  ('presentations', 17),
#  ('workflows', 17),
#  ('free', 17),
#  ('creative', 17),
#  ('directly', 17),
#  ('pregnancy', 17),
#  ('know', 17),
#  ('abilities', 17),
#  ('ongoing', 17),
#  ('spending', 17),
#  ('significant', 17),
#  ('among', 17),
#  ('initiative', 17),
#  ('international', 17),
#  ('together', 17),
#  ('center', 17),
#  ('transportation', 17),
#  ('reimbursement', 17),
#  ('clinical', 17),
#  ('sales', 17),
#  ('certifications', 17),
#  ('consumer', 17),
#  ('given', 17),
#  ('mantech', 17),
#  ('ms', 16),
#  ('performing', 16),
#  ('modern', 16),
#  ('expected', 16),
#  ('ancestry', 16),
#  ('explore', 16),
#  ('acquisition', 16),
#  ('integrate', 16),
#  ('trust', 16),
#  ('overall', 16),
#  ('tech', 16),
#  ('valuable', 16),
#  ('unstructured', 16),
#  ('interpersonal', 16),
#  ('inform', 16),
#  ('monitoring', 16),
#  ('hire', 16),
#  ('listed', 16),
#  ('upon', 16),
#  ('regular', 16),
#  ('control', 16),
#  ('rate', 16),
#  ('savings', 16),
#  ('legal', 16),
#  ('relationships', 16),
#  ('account', 16),
#  ('vary', 16),
#  ('accept', 16),
#  ('characteristic', 16),
#  ('proven', 16),
#  ('emerging', 16),
#  ('feedback', 16),
#  ('translate', 16),
#  ('effectiveness', 16),
#  ('creation', 16),
#  ('pto', 16),
#  ('specialized', 16),
#  ('online', 16),
#  ('selected', 16),
#  ('incentive', 16),
#  ('associates', 16),
#  ('ordinance', 16),
#  ('mtsi', 16),
#  ('bayer', 16),
#  ('encouraged', 15),
#  ('engineer', 15),
#  ('inc', 15),
#  ('users', 15),
#  ('report', 15),
#  ('advance', 15),
#  ('eeo', 15),
#  ('generate', 15),
#  ('mentor', 15),
#  ('website', 15),
#  ('wellness', 15),
#  ('execute', 15),
#  ('ensuring', 15),
#  ('solid', 15),
#  ('nlp', 15),
#  ('requirement', 15),
#  ('organizations', 15),
#  ('improving', 15),
#  ('hour', 15),
#  ('delivers', 15),
#  ('reviews', 15),
#  ('commercial', 15),
#  ('largest', 15),
#  ('independent', 15),
#  ('grade', 15),
#  ('structures', 15),
#  ('share', 15),
#  ('biology', 15),
#  ('accredited', 15),
#  ('clearly', 15),
#  ('8', 15),
#  ('laws', 15),
#  ('communications', 15),
#  ('depending', 15),
#  ('category', 15),
#  ('everyone', 15),
#  ('collaborating', 15),
#  ('colleagues', 15),
#  ('extraction', 15),
#  ('practical', 15),
#  ('outside', 15),
#  ('achieve', 15),
#  ('managers', 15),
#  ('facilitate', 15),
#  ('division', 15),
#  ('scripts', 15),
#  ('gs', 15),
#  ('realtor', 15),
#  ('source', 15),
#  ('adstra', 15),
#  ('vanderbilt', 15),
#  ('determine', 14),
#  ('operating', 14),
#  ('validation', 14),
#  ('sponsorship', 14),
#  ('columbia', 14),
#  ('series', 14),
#  ('talent', 14),
#  ('highest', 14),
#  ('gather', 14),
#  ('deploy', 14),
#  ('latest', 14),
#  ('markets', 14),
#  ('serve', 14),
#  ('requests', 14),
#  ('several', 14),
#  ('departments', 14),
#  ('staffing', 14),
#  ('placement', 14),
#  ('12', 14),
#  ('uses', 14),
#  ('risk', 14),
#  ('efforts', 14),
#  ('courses', 14),
#  ('pandas', 14),
#  ('proud', 14),
#  ('accommodations', 14),
#  ('fl', 14),
#  ('art', 14),
#  ('output', 14),
#  ('generous', 14),
#  ('students', 14),
#  ('frontier', 14),
#  ('makes', 14),
#  ('proof', 14),
#  ('priority', 14),
#  ('eligibility', 14),
#  ('automated', 14),
#  ('goal', 14),
#  ('preparation', 14),
#  ('manipulation', 14),
#  ('internship', 14),
#  ('leverage', 14),
#  ('important', 14),
#  ('supply', 14),
#  ('prescriptive', 14),
#  ('businesses', 14),
#  ('base', 14),
#  ('air', 14),
#  ('teaching', 14),
#  ('co', 14),
#  ('purpose', 14),
#  ('association', 14),
#  ('according', 13),
#  ('disabled', 13),
#  ('want', 13),
#  ('poly', 13),
#  ('anomaly', 13),
#  ('neural', 13),
#  ('web', 13),
#  ('workplace', 13),
#  ('document', 13),
#  ('submit', 13),
#  ('benefit', 13),
#  ('regarding', 13),
#  ('uncover', 13),
#  ('developers', 13),
#  ('components', 13),
#  ('workforce', 13),
#  ('located', 13),
#  ('libraries', 13),
#  ('oral', 13),
#  ('professionals', 13),
#  ('strive', 13),
#  ('possess', 13),
#  ('architecture', 13),
#  ('leader', 13),
#  ('survey', 13),
#  ('desire', 13),
#  ('countries', 13),
#  ('audiences', 13),
#  ('sharing', 13),
#  ('details', 13),
#  ('multi', 13),
#  ('expert', 13),
#  ('due', 13),
#  ('passion', 13),
#  ('small', 13),
#  ('embrace', 13),
#  ('exciting', 13),
#  ('schedules', 13),
#  ('consulting', 13),
#  ('characteristics', 13),
#  ('successfully', 13),
#  ('battelle', 13),
#  ('0', 13),
#  ('citizen', 13),
#  ('shift', 13),
#  ('nc', 13),
#  ('look', 13),
#  ('matlab', 13),
#  ('week', 13),
#  ('caterpillar', 13),
#  ('analysts', 13),
#  ('driving', 13),
#  ('rewards', 13),
#  ('aeronautical', 13),
#  ('hospital', 13),
#  ('bs', 12),
#  ('challenging', 12),
#  ('welcome', 12),
#  ('discover', 12),
#  ('view', 12),
#  ('privacy', 12),
#  ('experiments', 12),
#  ('validate', 12),
#  ('50', 12),
#  ('country', 12),
#  ('track', 12),
#  ('quickly', 12),
#  ('pre', 12),
#  ('provided', 12),
#  ('mentorship', 12),
#  ('worldwide', 12),
#  ('interpreting', 12),
#  ('interest', 12),
#  ('strongly', 12),
#  ('croptix', 12),
#  ('keep', 12),
#  ('deadlines', 12),
#  ('hired', 12),
#  ('posting', 12),
#  ('request', 12),
#  ('could', 12),
#  ('requires', 12),
#  ('pytorch', 12),
#  ('delivering', 12),
#  ('graduate', 12),
#  ('cultural', 12),
#  ('attend', 12),
#  ('broad', 12),
#  ('carrying', 12),
#  ('another', 12),
#  ('reviewed', 12),
#  ('enjoy', 12),
#  ('ethnicity', 12),
#  ('associate', 12),
#  ('either', 12),
#  ('study', 12),
#  ('physics', 12),
#  ('9', 12),
#  ('applies', 12),
#  ('skilled', 12),
#  ('scale', 12),
#  ('estimate', 12),
#  ('become', 12),
#  ('forward', 12),
#  ('difference', 12),
#  ('consider', 12),
#  ('finance', 12),
#  ('cases', 12),
#  ...]

# %%
data_scientist_top_skills = {'python': 141, 'sql': 121, 'r': 93, 'tableau': 49, 'aws': 32}

# %%
#if wanted to automate getting most common skills, could make a list of most common ones manually, and search for them
backend_skills = ['python', 'java', 'ruby', 'node', 'django', 'flask', 'sql', 'nosql', 'linux', 'aws', 'docker', 
                  'api', 'git', 'php', 'ruby', 'express', 'api', 'json', 'xml', 'github']

frontend_skills = ['html', 'css', 'javascript', 'react', 'angular', 'vue', 'ux', 'ui', 'redux', 'vuex', 'sass', 'less'
                'jquery', 'version', 'testing', 'unit', 'stylus', 'gui']

#fullstack is both of the above combined

#testing here is a/b testing, removing white space may have messed this word here. 
#google is also referring to google sheets and power is PowerBI
data_analyst_skills = ['python', 'r', 'tableau', 'power', 'matplotlib', 'ggplot2', 'sql', 'excel', 'google',
                       'statistics', 'statistical', 'cleaning', 'testing', 'visualization', 'business']

#Machine Learning, Deep Learning, Predictive Modeling are the full version of first three, and vision is computer vision
data_scientist_skills = ['machine', 'deep', 'predictive', 'spark', 'nlp', 'vision', 'ai', 'scikit', 'tensorflow', 
                         'pytorch', 'matlab', 'algebra', 'calculus']


it_support_skills = ['troubleshooting', 'operating', 'windows', 'macos', 'linux', 'network', 'cybersecurity', 
                     'desktop', 'aws', 'azure', 'gcp']

penetration_tester_skills = [
    "Ethical Hacking",
    "Network Scanning",
    "Vulnerability Assessment",
    "Exploitation Techniques",
    "Web Application Testing",
    "Wireless Network Security",
    "Security Tools (Metasploit, Wireshark, Nmap)",
    "Report Writing",
    "Compliance Standards (ISO 27001, NIST)",
    "Social Engineering"]

security_analyst_skills = penetration_tester_skills

ux_designer_skills = [
    "User Research",
    "Information Architecture",
    "Wireframing and Prototyping",
    "Usability Testing",
    "Interaction Design",
    "Persona Development",
    "User Flows",
    "Visual Design Principles",
    "Design Thinking",
    "UX/UI Tools (Sketch, Figma, Adobe XD)"
]

ui_designer_skills = [
    "Visual Design",
    "Graphic Design Software (Adobe Creative Suite)",
    "Color Theory",
    "Typography",
    "Icon Design",
    "User Interface Patterns",
    "Responsive Design",
    "Design Systems",
    "Animation",
    "Collaboration with Developers"
]
